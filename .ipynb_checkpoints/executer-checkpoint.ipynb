# %%
from naverreader import naverreader
from strategy_ma import strategy_ma
import pandas as pd

# %%
nr = naverreader()
nr.get_naver_total(days=2500)

# %%
stra = strategy_ma(30, 120, 60, 3000)

# %%
result = stra.run('20200221')
# Out:
# 진행률 0.0%, 현재 소요시간 0.01분
# 진행률 0.13%, 현재 소요시간 0.02분
# 진행률 0.26%, 현재 소요시간 0.03분
# 진행률 0.39%, 현재 소요시간 0.05분
# 진행률 0.52%, 현재 소요시간 0.06분
# 진행률 0.65%, 현재 소요시간 0.08분
# 진행률 0.78%, 현재 소요시간 0.09분
# 진행률 0.91%, 현재 소요시간 0.1분
# 진행률 1.04%, 현재 소요시간 0.12분
# 진행률 1.16%, 현재 소요시간 0.13분
# 진행률 1.29%, 현재 소요시간 0.14분
# 진행률 1.42%, 현재 소요시간 0.16분
# 진행률 1.55%, 현재 소요시간 0.17분
# 진행률 1.68%, 현재 소요시간 0.18분
# 진행률 1.81%, 현재 소요시간 0.2분
# 진행률 1.94%, 현재 소요시간 0.21분
# 진행률 2.07%, 현재 소요시간 0.22분
# 진행률 2.2%, 현재 소요시간 0.24분
# 진행률 2.33%, 현재 소요시간 0.25분
# 진행률 2.46%, 현재 소요시간 0.27분
# 진행률 2.59%, 현재 소요시간 0.28분
# 진행률 2.72%, 현재 소요시간 0.29분
# 진행률 2.85%, 현재 소요시간 0.31분
# 진행률 2.98%, 현재 소요시간 0.33분
# 진행률 3.11%, 현재 소요시간 0.34분
# 진행률 3.24%, 현재 소요시간 0.36분
# 진행률 3.36%, 현재 소요시간 0.37분
# 진행률 3.49%, 현재 소요시간 0.38분
# 진행률 3.62%, 현재 소요시간 0.4분
# 진행률 3.75%, 현재 소요시간 0.41분
# 진행률 3.88%, 현재 소요시간 0.43분
# 진행률 4.01%, 현재 소요시간 0.44분
# 진행률 4.14%, 현재 소요시간 0.46분
# 진행률 4.27%, 현재 소요시간 0.47분
# 진행률 4.4%, 현재 소요시간 0.49분
# 진행률 4.53%, 현재 소요시간 0.51분
# 진행률 4.66%, 현재 소요시간 0.52분
# 진행률 4.79%, 현재 소요시간 0.54분
# 진행률 4.92%, 현재 소요시간 0.55분
# 진행률 5.05%, 현재 소요시간 0.57분
# 진행률 5.18%, 현재 소요시간 0.59분
# 진행률 5.31%, 현재 소요시간 0.61분
# 진행률 5.44%, 현재 소요시간 0.63분
# 진행률 5.57%, 현재 소요시간 0.64분
# 진행률 5.69%, 현재 소요시간 0.66분
# 진행률 5.82%, 현재 소요시간 0.68분
# 진행률 5.95%, 현재 소요시간 0.69분
# 진행률 6.08%, 현재 소요시간 0.71분
# 진행률 6.21%, 현재 소요시간 0.72분
# 진행률 6.34%, 현재 소요시간 0.74분
# 진행률 6.47%, 현재 소요시간 0.76분
# 진행률 6.6%, 현재 소요시간 0.78분
# 진행률 6.73%, 현재 소요시간 0.79분
# 진행률 6.86%, 현재 소요시간 0.81분
# 진행률 6.99%, 현재 소요시간 0.82분
# 진행률 7.12%, 현재 소요시간 0.84분
# 진행률 7.25%, 현재 소요시간 0.86분
# 진행률 7.38%, 현재 소요시간 0.87분
# 진행률 7.51%, 현재 소요시간 0.89분
# 진행률 7.64%, 현재 소요시간 0.9분
# 진행률 7.77%, 현재 소요시간 0.91분
# 진행률 7.89%, 현재 소요시간 0.92분
# 진행률 8.02%, 현재 소요시간 0.93분
# 진행률 8.15%, 현재 소요시간 0.95분
# 진행률 8.28%, 현재 소요시간 0.96분
# 진행률 8.41%, 현재 소요시간 0.97분
# 진행률 8.54%, 현재 소요시간 0.98분
# 진행률 8.67%, 현재 소요시간 0.99분
# 진행률 8.8%, 현재 소요시간 1.0분
# 진행률 8.93%, 현재 소요시간 1.01분
# 진행률 9.06%, 현재 소요시간 1.02분
# 진행률 9.19%, 현재 소요시간 1.04분
# 진행률 9.32%, 현재 소요시간 1.05분
# 진행률 9.45%, 현재 소요시간 1.06분
# 진행률 9.58%, 현재 소요시간 1.07분
# 진행률 9.71%, 현재 소요시간 1.08분
# 진행률 9.84%, 현재 소요시간 1.09분
# 진행률 9.97%, 현재 소요시간 1.1분
# 진행률 10.09%, 현재 소요시간 1.11분
# 진행률 10.22%, 현재 소요시간 1.12분
# 진행률 10.35%, 현재 소요시간 1.14분
# 진행률 10.48%, 현재 소요시간 1.15분
# 진행률 10.61%, 현재 소요시간 1.16분
# 진행률 10.74%, 현재 소요시간 1.17분
# 진행률 10.87%, 현재 소요시간 1.18분
# 진행률 11.0%, 현재 소요시간 1.19분
# 진행률 11.13%, 현재 소요시간 1.2분
# 진행률 11.26%, 현재 소요시간 1.22분
# 진행률 11.39%, 현재 소요시간 1.23분
# 진행률 11.52%, 현재 소요시간 1.24분
# 진행률 11.65%, 현재 소요시간 1.25분
# 진행률 11.78%, 현재 소요시간 1.26분
# 진행률 11.91%, 현재 소요시간 1.27분
# 진행률 12.04%, 현재 소요시간 1.28분
# 진행률 12.17%, 현재 소요시간 1.29분
# 진행률 12.3%, 현재 소요시간 1.3분
# 진행률 12.42%, 현재 소요시간 1.32분
# 진행률 12.55%, 현재 소요시간 1.33분
# 진행률 12.68%, 현재 소요시간 1.34분
# 진행률 12.81%, 현재 소요시간 1.35분
# 진행률 12.94%, 현재 소요시간 1.37분
# 진행률 13.07%, 현재 소요시간 1.38분
# 진행률 13.2%, 현재 소요시간 1.39분
# 진행률 13.33%, 현재 소요시간 1.41분
# 진행률 13.46%, 현재 소요시간 1.42분
# 진행률 13.59%, 현재 소요시간 1.43분
# 진행률 13.72%, 현재 소요시간 1.44분
# 진행률 13.85%, 현재 소요시간 1.46분
# 진행률 13.98%, 현재 소요시간 1.47분
# 진행률 14.11%, 현재 소요시간 1.48분
# 진행률 14.24%, 현재 소요시간 1.49분
# 진행률 14.37%, 현재 소요시간 1.51분
# 진행률 14.5%, 현재 소요시간 1.52분
# 진행률 14.62%, 현재 소요시간 1.53분
# 진행률 14.75%, 현재 소요시간 1.54분
# 진행률 14.88%, 현재 소요시간 1.55분
# 진행률 15.01%, 현재 소요시간 1.56분
# 진행률 15.14%, 현재 소요시간 1.58분
# 진행률 15.27%, 현재 소요시간 1.59분
# 진행률 15.4%, 현재 소요시간 1.6분
# 진행률 15.53%, 현재 소요시간 1.61분
# 진행률 15.66%, 현재 소요시간 1.62분
# 진행률 15.79%, 현재 소요시간 1.64분
# 진행률 15.92%, 현재 소요시간 1.65분
# 진행률 16.05%, 현재 소요시간 1.66분
# 진행률 16.18%, 현재 소요시간 1.67분
# 진행률 16.31%, 현재 소요시간 1.68분
# 진행률 16.44%, 현재 소요시간 1.7분
# 진행률 16.57%, 현재 소요시간 1.71분
# 진행률 16.7%, 현재 소요시간 1.72분
# 진행률 16.82%, 현재 소요시간 1.73분
# 진행률 16.95%, 현재 소요시간 1.74분
# 진행률 17.08%, 현재 소요시간 1.76분
# 진행률 17.21%, 현재 소요시간 1.77분
# 진행률 17.34%, 현재 소요시간 1.78분
# 진행률 17.47%, 현재 소요시간 1.79분
# 진행률 17.6%, 현재 소요시간 1.8분
# 진행률 17.73%, 현재 소요시간 1.82분
# 진행률 17.86%, 현재 소요시간 1.83분
# 진행률 17.99%, 현재 소요시간 1.84분
# 진행률 18.12%, 현재 소요시간 1.86분
# 진행률 18.25%, 현재 소요시간 1.87분
# 진행률 18.38%, 현재 소요시간 1.88분
# 진행률 18.51%, 현재 소요시간 1.9분
# 진행률 18.64%, 현재 소요시간 1.91분
# 진행률 18.77%, 현재 소요시간 1.92분
# 진행률 18.9%, 현재 소요시간 1.93분
# 진행률 19.03%, 현재 소요시간 1.95분
# 진행률 19.15%, 현재 소요시간 1.96분
# 진행률 19.28%, 현재 소요시간 1.97분
# 진행률 19.41%, 현재 소요시간 1.98분
# 진행률 19.54%, 현재 소요시간 2.0분
# 진행률 19.67%, 현재 소요시간 2.01분
# 진행률 19.8%, 현재 소요시간 2.02분
# 진행률 19.93%, 현재 소요시간 2.03분
# 진행률 20.06%, 현재 소요시간 2.04분
# 진행률 20.19%, 현재 소요시간 2.06분
# 진행률 20.32%, 현재 소요시간 2.07분
# 진행률 20.45%, 현재 소요시간 2.08분
# 진행률 20.58%, 현재 소요시간 2.09분
# 진행률 20.71%, 현재 소요시간 2.1분
# 진행률 20.84%, 현재 소요시간 2.12분
# 진행률 20.97%, 현재 소요시간 2.13분
# 진행률 21.1%, 현재 소요시간 2.14분
# 진행률 21.23%, 현재 소요시간 2.15분
# 진행률 21.35%, 현재 소요시간 2.16분
# 진행률 21.48%, 현재 소요시간 2.18분
# 진행률 21.61%, 현재 소요시간 2.19분
# 진행률 21.74%, 현재 소요시간 2.2분
# 진행률 21.87%, 현재 소요시간 2.21분
# 진행률 22.0%, 현재 소요시간 2.22분
# 진행률 22.13%, 현재 소요시간 2.23분
# 진행률 22.26%, 현재 소요시간 2.24분
# 진행률 22.39%, 현재 소요시간 2.25분
# 진행률 22.52%, 현재 소요시간 2.27분
# 진행률 22.65%, 현재 소요시간 2.28분
# 진행률 22.78%, 현재 소요시간 2.29분
# 진행률 22.91%, 현재 소요시간 2.3분
# 진행률 23.04%, 현재 소요시간 2.31분
# 진행률 23.17%, 현재 소요시간 2.32분
# 진행률 23.3%, 현재 소요시간 2.33분
# 진행률 23.43%, 현재 소요시간 2.35분
# 진행률 23.55%, 현재 소요시간 2.36분
# 진행률 23.68%, 현재 소요시간 2.37분
# 진행률 23.81%, 현재 소요시간 2.38분
# 진행률 23.94%, 현재 소요시간 2.39분
# 진행률 24.07%, 현재 소요시간 2.4분
# 진행률 24.2%, 현재 소요시간 2.41분
# 진행률 24.33%, 현재 소요시간 2.42분
# 진행률 24.46%, 현재 소요시간 2.44분
# 진행률 24.59%, 현재 소요시간 2.45분
# 진행률 24.72%, 현재 소요시간 2.46분
# 진행률 24.85%, 현재 소요시간 2.47분
# 진행률 24.98%, 현재 소요시간 2.48분
# 진행률 25.11%, 현재 소요시간 2.49분
# 진행률 25.24%, 현재 소요시간 2.5분
# 진행률 25.37%, 현재 소요시간 2.51분
# 진행률 25.5%, 현재 소요시간 2.52분
# 진행률 25.63%, 현재 소요시간 2.54분
# 진행률 25.75%, 현재 소요시간 2.55분
# 진행률 25.88%, 현재 소요시간 2.56분
# 진행률 26.01%, 현재 소요시간 2.57분
# 진행률 26.14%, 현재 소요시간 2.58분
# 진행률 26.27%, 현재 소요시간 2.59분
# 진행률 26.4%, 현재 소요시간 2.6분
# 진행률 26.53%, 현재 소요시간 2.61분
# 진행률 26.66%, 현재 소요시간 2.62분
# 진행률 26.79%, 현재 소요시간 2.64분
# 진행률 26.92%, 현재 소요시간 2.65분
# 진행률 27.05%, 현재 소요시간 2.66분
# 진행률 27.18%, 현재 소요시간 2.67분
# 진행률 27.31%, 현재 소요시간 2.68분
# 진행률 27.44%, 현재 소요시간 2.69분
# 진행률 27.57%, 현재 소요시간 2.7분
# 진행률 27.7%, 현재 소요시간 2.72분
# 진행률 27.83%, 현재 소요시간 2.73분
# 진행률 27.96%, 현재 소요시간 2.74분
# 진행률 28.08%, 현재 소요시간 2.75분
# 진행률 28.21%, 현재 소요시간 2.76분
# 진행률 28.34%, 현재 소요시간 2.77분
# 진행률 28.47%, 현재 소요시간 2.78분
# 진행률 28.6%, 현재 소요시간 2.79분
# 진행률 28.73%, 현재 소요시간 2.81분
# 진행률 28.86%, 현재 소요시간 2.82분
# 진행률 28.99%, 현재 소요시간 2.83분
# 진행률 29.12%, 현재 소요시간 2.84분
# 진행률 29.25%, 현재 소요시간 2.85분
# 진행률 29.38%, 현재 소요시간 2.86분
# 진행률 29.51%, 현재 소요시간 2.87분
# 진행률 29.64%, 현재 소요시간 2.89분
# 진행률 29.77%, 현재 소요시간 2.9분
# 진행률 29.9%, 현재 소요시간 2.91분
# 진행률 30.03%, 현재 소요시간 2.92분
# 진행률 30.16%, 현재 소요시간 2.93분
# 진행률 30.28%, 현재 소요시간 2.94분
# 진행률 30.41%, 현재 소요시간 2.95분
# 진행률 30.54%, 현재 소요시간 2.96분
# 진행률 30.67%, 현재 소요시간 2.98분
# 진행률 30.8%, 현재 소요시간 2.99분
# 진행률 30.93%, 현재 소요시간 3.0분
# 진행률 31.06%, 현재 소요시간 3.01분
# 진행률 31.19%, 현재 소요시간 3.02분
# 진행률 31.32%, 현재 소요시간 3.03분
# 진행률 31.45%, 현재 소요시간 3.04분
# 진행률 31.58%, 현재 소요시간 3.06분
# 진행률 31.71%, 현재 소요시간 3.07분
# 진행률 31.84%, 현재 소요시간 3.08분
# 진행률 31.97%, 현재 소요시간 3.09분
# 진행률 32.1%, 현재 소요시간 3.1분
# 진행률 32.23%, 현재 소요시간 3.11분
# 진행률 32.36%, 현재 소요시간 3.13분
# 진행률 32.48%, 현재 소요시간 3.14분
# 진행률 32.61%, 현재 소요시간 3.15분
# 진행률 32.74%, 현재 소요시간 3.16분
# 진행률 32.87%, 현재 소요시간 3.18분
# 진행률 33.0%, 현재 소요시간 3.19분
# 진행률 33.13%, 현재 소요시간 3.2분
# 진행률 33.26%, 현재 소요시간 3.21분
# 진행률 33.39%, 현재 소요시간 3.22분
# 진행률 33.52%, 현재 소요시간 3.24분
# 진행률 33.65%, 현재 소요시간 3.25분
# 진행률 33.78%, 현재 소요시간 3.26분
# 진행률 33.91%, 현재 소요시간 3.27분
# 진행률 34.04%, 현재 소요시간 3.29분
# 진행률 34.17%, 현재 소요시간 3.3분
# 진행률 34.3%, 현재 소요시간 3.31분
# 진행률 34.43%, 현재 소요시간 3.32분
# 진행률 34.56%, 현재 소요시간 3.34분
# 진행률 34.69%, 현재 소요시간 3.35분
# 진행률 34.81%, 현재 소요시간 3.36분
# 진행률 34.94%, 현재 소요시간 3.37분
# 진행률 35.07%, 현재 소요시간 3.39분
# 진행률 35.2%, 현재 소요시간 3.4분
# 진행률 35.33%, 현재 소요시간 3.41분
# 진행률 35.46%, 현재 소요시간 3.42분
# 진행률 35.59%, 현재 소요시간 3.43분
# 진행률 35.72%, 현재 소요시간 3.45분
# 진행률 35.85%, 현재 소요시간 3.46분
# 진행률 35.98%, 현재 소요시간 3.47분
# 진행률 36.11%, 현재 소요시간 3.49분
# 진행률 36.24%, 현재 소요시간 3.5분
# 진행률 36.37%, 현재 소요시간 3.51분
# 진행률 36.5%, 현재 소요시간 3.52분
# 진행률 36.63%, 현재 소요시간 3.53분
# 진행률 36.76%, 현재 소요시간 3.55분
# 진행률 36.89%, 현재 소요시간 3.56분
# 진행률 37.01%, 현재 소요시간 3.57분
# 진행률 37.14%, 현재 소요시간 3.58분
# 진행률 37.27%, 현재 소요시간 3.59분
# 진행률 37.4%, 현재 소요시간 3.61분
# 진행률 37.53%, 현재 소요시간 3.62분
# 진행률 37.66%, 현재 소요시간 3.63분
# 진행률 37.79%, 현재 소요시간 3.64분
# 진행률 37.92%, 현재 소요시간 3.65분
# 진행률 38.05%, 현재 소요시간 3.66분
# 진행률 38.18%, 현재 소요시간 3.68분
# 진행률 38.31%, 현재 소요시간 3.69분
# 진행률 38.44%, 현재 소요시간 3.7분
# 진행률 38.57%, 현재 소요시간 3.71분
# 진행률 38.7%, 현재 소요시간 3.72분
# 진행률 38.83%, 현재 소요시간 3.73분
# 진행률 38.96%, 현재 소요시간 3.74분
# 진행률 39.09%, 현재 소요시간 3.76분
# 진행률 39.21%, 현재 소요시간 3.77분
# 진행률 39.34%, 현재 소요시간 3.78분
# 진행률 39.47%, 현재 소요시간 3.79분
# 진행률 39.6%, 현재 소요시간 3.8분
# 진행률 39.73%, 현재 소요시간 3.81분
# 진행률 39.86%, 현재 소요시간 3.82분
# 진행률 39.99%, 현재 소요시간 3.84분
# 진행률 40.12%, 현재 소요시간 3.85분
# 진행률 40.25%, 현재 소요시간 3.86분
# 진행률 40.38%, 현재 소요시간 3.87분
# 진행률 40.51%, 현재 소요시간 3.88분
# 진행률 40.64%, 현재 소요시간 3.89분
# 진행률 40.77%, 현재 소요시간 3.9분
# 진행률 40.9%, 현재 소요시간 3.91분
# 진행률 41.03%, 현재 소요시간 3.93분
# 진행률 41.16%, 현재 소요시간 3.94분
# 진행률 41.29%, 현재 소요시간 3.95분
# 진행률 41.42%, 현재 소요시간 3.96분
# 진행률 41.54%, 현재 소요시간 3.97분
# 진행률 41.67%, 현재 소요시간 3.98분
# 진행률 41.8%, 현재 소요시간 3.99분
# 진행률 41.93%, 현재 소요시간 4.0분
# 진행률 42.06%, 현재 소요시간 4.02분
# 진행률 42.19%, 현재 소요시간 4.03분
# 진행률 42.32%, 현재 소요시간 4.04분
# 진행률 42.45%, 현재 소요시간 4.05분
# 진행률 42.58%, 현재 소요시간 4.06분
# 진행률 42.71%, 현재 소요시간 4.07분
# 진행률 42.84%, 현재 소요시간 4.08분
# 진행률 42.97%, 현재 소요시간 4.09분
# 진행률 43.1%, 현재 소요시간 4.1분
# 진행률 43.23%, 현재 소요시간 4.12분
# 진행률 43.36%, 현재 소요시간 4.13분
# 진행률 43.49%, 현재 소요시간 4.14분
# 진행률 43.62%, 현재 소요시간 4.15분
# 진행률 43.74%, 현재 소요시간 4.16분
# 진행률 43.87%, 현재 소요시간 4.17분
# 진행률 44.0%, 현재 소요시간 4.18분
# 진행률 44.13%, 현재 소요시간 4.19분
# 진행률 44.26%, 현재 소요시간 4.21분
# 진행률 44.39%, 현재 소요시간 4.22분
# 진행률 44.52%, 현재 소요시간 4.23분
# 진행률 44.65%, 현재 소요시간 4.24분
# 진행률 44.78%, 현재 소요시간 4.25분
# 진행률 44.91%, 현재 소요시간 4.26분
# 진행률 45.04%, 현재 소요시간 4.28분
# 진행률 45.17%, 현재 소요시간 4.29분
# 진행률 45.3%, 현재 소요시간 4.3분
# 진행률 45.43%, 현재 소요시간 4.31분
# 진행률 45.56%, 현재 소요시간 4.32분
# 진행률 45.69%, 현재 소요시간 4.33분
# 진행률 45.82%, 현재 소요시간 4.35분
# 진행률 45.94%, 현재 소요시간 4.36분
# 진행률 46.07%, 현재 소요시간 4.37분
# 진행률 46.2%, 현재 소요시간 4.38분
# 진행률 46.33%, 현재 소요시간 4.39분
# 진행률 46.46%, 현재 소요시간 4.4분
# 진행률 46.59%, 현재 소요시간 4.41분
# 진행률 46.72%, 현재 소요시간 4.43분
# 진행률 46.85%, 현재 소요시간 4.44분
# 진행률 46.98%, 현재 소요시간 4.45분
# 진행률 47.11%, 현재 소요시간 4.46분
# 진행률 47.24%, 현재 소요시간 4.47분
# 진행률 47.37%, 현재 소요시간 4.48분
# 진행률 47.5%, 현재 소요시간 4.49분
# 진행률 47.63%, 현재 소요시간 4.51분
# 진행률 47.76%, 현재 소요시간 4.52분
# 진행률 47.89%, 현재 소요시간 4.53분
# 진행률 48.02%, 현재 소요시간 4.54분
# 진행률 48.14%, 현재 소요시간 4.55분
# 진행률 48.27%, 현재 소요시간 4.56분
# 진행률 48.4%, 현재 소요시간 4.58분
# 진행률 48.53%, 현재 소요시간 4.59분
# 진행률 48.66%, 현재 소요시간 4.6분
# 진행률 48.79%, 현재 소요시간 4.61분
# 진행률 48.92%, 현재 소요시간 4.62분
# 진행률 49.05%, 현재 소요시간 4.63분
# 진행률 49.18%, 현재 소요시간 4.65분
# 진행률 49.31%, 현재 소요시간 4.66분
# 진행률 49.44%, 현재 소요시간 4.67분
# 진행률 49.57%, 현재 소요시간 4.68분
# 진행률 49.7%, 현재 소요시간 4.69분
# 진행률 49.83%, 현재 소요시간 4.71분
# 진행률 49.96%, 현재 소요시간 4.72분
# 진행률 50.09%, 현재 소요시간 4.73분
# 진행률 50.22%, 현재 소요시간 4.74분
# 진행률 50.35%, 현재 소요시간 4.75분
# 진행률 50.47%, 현재 소요시간 4.77분
# 진행률 50.6%, 현재 소요시간 4.78분
# 진행률 50.73%, 현재 소요시간 4.79분
# 진행률 50.86%, 현재 소요시간 4.8분
# 진행률 50.99%, 현재 소요시간 4.81분
# 진행률 51.12%, 현재 소요시간 4.83분
# 진행률 51.25%, 현재 소요시간 4.84분
# 진행률 51.38%, 현재 소요시간 4.85분
# 진행률 51.51%, 현재 소요시간 4.86분
# 진행률 51.64%, 현재 소요시간 4.87분
# 진행률 51.77%, 현재 소요시간 4.88분
# 진행률 51.9%, 현재 소요시간 4.9분
# 진행률 52.03%, 현재 소요시간 4.91분
# 진행률 52.16%, 현재 소요시간 4.92분
# 진행률 52.29%, 현재 소요시간 4.93분
# 진행률 52.42%, 현재 소요시간 4.94분
# 진행률 52.55%, 현재 소요시간 4.95분
# 진행률 52.67%, 현재 소요시간 4.96분
# 진행률 52.8%, 현재 소요시간 4.98분
# 진행률 52.93%, 현재 소요시간 4.99분
# 진행률 53.06%, 현재 소요시간 5.0분
# 진행률 53.19%, 현재 소요시간 5.01분
# 진행률 53.32%, 현재 소요시간 5.02분
# 진행률 53.45%, 현재 소요시간 5.03분
# 진행률 53.58%, 현재 소요시간 5.04분
# 진행률 53.71%, 현재 소요시간 5.05분
# 진행률 53.84%, 현재 소요시간 5.07분
# 진행률 53.97%, 현재 소요시간 5.08분
# 진행률 54.1%, 현재 소요시간 5.09분
# 진행률 54.23%, 현재 소요시간 5.1분
# 진행률 54.36%, 현재 소요시간 5.11분
# 진행률 54.49%, 현재 소요시간 5.12분
# 진행률 54.62%, 현재 소요시간 5.13분
# 진행률 54.75%, 현재 소요시간 5.15분
# 진행률 54.87%, 현재 소요시간 5.16분
# 진행률 55.0%, 현재 소요시간 5.17분
# 진행률 55.13%, 현재 소요시간 5.18분
# 진행률 55.26%, 현재 소요시간 5.19분
# 진행률 55.39%, 현재 소요시간 5.2분
# 진행률 55.52%, 현재 소요시간 5.21분
# 진행률 55.65%, 현재 소요시간 5.22분
# 진행률 55.78%, 현재 소요시간 5.23분
# 진행률 55.91%, 현재 소요시간 5.24분
# 진행률 56.04%, 현재 소요시간 5.26분
# 진행률 56.17%, 현재 소요시간 5.27분
# 진행률 56.3%, 현재 소요시간 5.28분
# 진행률 56.43%, 현재 소요시간 5.29분
# 진행률 56.56%, 현재 소요시간 5.3분
# 진행률 56.69%, 현재 소요시간 5.31분
# 진행률 56.82%, 현재 소요시간 5.32분
# 진행률 56.95%, 현재 소요시간 5.33분
# 진행률 57.08%, 현재 소요시간 5.34분
# 진행률 57.2%, 현재 소요시간 5.36분
# 진행률 57.33%, 현재 소요시간 5.37분
# 진행률 57.46%, 현재 소요시간 5.38분
# 진행률 57.59%, 현재 소요시간 5.39분
# 진행률 57.72%, 현재 소요시간 5.4분
# 진행률 57.85%, 현재 소요시간 5.41분
# 진행률 57.98%, 현재 소요시간 5.42분
# 진행률 58.11%, 현재 소요시간 5.43분
# 진행률 58.24%, 현재 소요시간 5.45분
# 진행률 58.37%, 현재 소요시간 5.46분
# 진행률 58.5%, 현재 소요시간 5.47분
# 진행률 58.63%, 현재 소요시간 5.48분
# 진행률 58.76%, 현재 소요시간 5.49분
# 진행률 58.89%, 현재 소요시간 5.5분
# 진행률 59.02%, 현재 소요시간 5.51분
# 진행률 59.15%, 현재 소요시간 5.52분
# 진행률 59.28%, 현재 소요시간 5.54분
# 진행률 59.4%, 현재 소요시간 5.55분
# 진행률 59.53%, 현재 소요시간 5.56분
# 진행률 59.66%, 현재 소요시간 5.57분
# 진행률 59.79%, 현재 소요시간 5.59분
# 진행률 59.92%, 현재 소요시간 5.6분
# 진행률 60.05%, 현재 소요시간 5.61분
# 진행률 60.18%, 현재 소요시간 5.62분
# 진행률 60.31%, 현재 소요시간 5.63분
# 진행률 60.44%, 현재 소요시간 5.64분
# 진행률 60.57%, 현재 소요시간 5.66분
# 진행률 60.7%, 현재 소요시간 5.67분
# 진행률 60.83%, 현재 소요시간 5.68분
# 진행률 60.96%, 현재 소요시간 5.69분
# 진행률 61.09%, 현재 소요시간 5.7분
# 진행률 61.22%, 현재 소요시간 5.71분
# 진행률 61.35%, 현재 소요시간 5.72분
# 진행률 61.48%, 현재 소요시간 5.74분
# 진행률 61.6%, 현재 소요시간 5.75분
# 진행률 61.73%, 현재 소요시간 5.76분
# 진행률 61.86%, 현재 소요시간 5.77분
# 진행률 61.99%, 현재 소요시간 5.78분
# 진행률 62.12%, 현재 소요시간 5.79분
# 진행률 62.25%, 현재 소요시간 5.8분
# 진행률 62.38%, 현재 소요시간 5.81분
# 진행률 62.51%, 현재 소요시간 5.83분
# 진행률 62.64%, 현재 소요시간 5.84분
# 진행률 62.77%, 현재 소요시간 5.85분
# 진행률 62.9%, 현재 소요시간 5.86분
# 진행률 63.03%, 현재 소요시간 5.87분
# 진행률 63.16%, 현재 소요시간 5.89분
# 진행률 63.29%, 현재 소요시간 5.9분
# 진행률 63.42%, 현재 소요시간 5.91분
# 진행률 63.55%, 현재 소요시간 5.92분
# 진행률 63.68%, 현재 소요시간 5.93분
# 진행률 63.81%, 현재 소요시간 5.94분
# 진행률 63.93%, 현재 소요시간 5.96분
# 진행률 64.06%, 현재 소요시간 5.98분
# 진행률 64.19%, 현재 소요시간 5.99분
# 진행률 64.32%, 현재 소요시간 6.01분
# 진행률 64.45%, 현재 소요시간 6.02분
# 진행률 64.58%, 현재 소요시간 6.03분
# 진행률 64.71%, 현재 소요시간 6.04분
# 진행률 64.84%, 현재 소요시간 6.06분
# 진행률 64.97%, 현재 소요시간 6.07분
# 진행률 65.1%, 현재 소요시간 6.08분
# 진행률 65.23%, 현재 소요시간 6.09분
# 진행률 65.36%, 현재 소요시간 6.1분
# 진행률 65.49%, 현재 소요시간 6.11분
# 진행률 65.62%, 현재 소요시간 6.13분
# 진행률 65.75%, 현재 소요시간 6.14분
# 진행률 65.88%, 현재 소요시간 6.15분
# 진행률 66.01%, 현재 소요시간 6.16분
# 진행률 66.13%, 현재 소요시간 6.17분
# 진행률 66.26%, 현재 소요시간 6.19분
# 진행률 66.39%, 현재 소요시간 6.2분
# 진행률 66.52%, 현재 소요시간 6.21분
# 진행률 66.65%, 현재 소요시간 6.22분
# 진행률 66.78%, 현재 소요시간 6.24분
# 진행률 66.91%, 현재 소요시간 6.25분
# 진행률 67.04%, 현재 소요시간 6.26분
# 진행률 67.17%, 현재 소요시간 6.27분
# 진행률 67.3%, 현재 소요시간 6.28분
# 진행률 67.43%, 현재 소요시간 6.3분
# 진행률 67.56%, 현재 소요시간 6.31분
# 진행률 67.69%, 현재 소요시간 6.32분
# 진행률 67.82%, 현재 소요시간 6.33분
# 진행률 67.95%, 현재 소요시간 6.35분
# 진행률 68.08%, 현재 소요시간 6.36분
# 진행률 68.21%, 현재 소요시간 6.37분
# 진행률 68.33%, 현재 소요시간 6.38분
# 진행률 68.46%, 현재 소요시간 6.4분
# 진행률 68.59%, 현재 소요시간 6.41분
# 진행률 68.72%, 현재 소요시간 6.42분
# 진행률 68.85%, 현재 소요시간 6.43분
# 진행률 68.98%, 현재 소요시간 6.44분
# 진행률 69.11%, 현재 소요시간 6.45분
# 진행률 69.24%, 현재 소요시간 6.47분
# 진행률 69.37%, 현재 소요시간 6.48분
# 진행률 69.5%, 현재 소요시간 6.49분
# 진행률 69.63%, 현재 소요시간 6.5분
# 진행률 69.76%, 현재 소요시간 6.51분
# 진행률 69.89%, 현재 소요시간 6.52분
# 진행률 70.02%, 현재 소요시간 6.53분
# 진행률 70.15%, 현재 소요시간 6.55분
# 진행률 70.28%, 현재 소요시간 6.56분
# 진행률 70.41%, 현재 소요시간 6.57분
# 진행률 70.53%, 현재 소요시간 6.58분
# 진행률 70.66%, 현재 소요시간 6.59분
# 진행률 70.79%, 현재 소요시간 6.6분
# 진행률 70.92%, 현재 소요시간 6.61분
# 진행률 71.05%, 현재 소요시간 6.63분
# 진행률 71.18%, 현재 소요시간 6.64분
# 진행률 71.31%, 현재 소요시간 6.65분
# 진행률 71.44%, 현재 소요시간 6.66분
# 진행률 71.57%, 현재 소요시간 6.67분
# 진행률 71.7%, 현재 소요시간 6.68분
# 진행률 71.83%, 현재 소요시간 6.69분
# 진행률 71.96%, 현재 소요시간 6.7분
# 진행률 72.09%, 현재 소요시간 6.71분
# 진행률 72.22%, 현재 소요시간 6.73분
# 진행률 72.35%, 현재 소요시간 6.74분
# 진행률 72.48%, 현재 소요시간 6.75분
# 진행률 72.61%, 현재 소요시간 6.76분
# 진행률 72.74%, 현재 소요시간 6.77분
# 진행률 72.86%, 현재 소요시간 6.78분
# 진행률 72.99%, 현재 소요시간 6.79분
# 진행률 73.12%, 현재 소요시간 6.8분
# 진행률 73.25%, 현재 소요시간 6.81분
# 진행률 73.38%, 현재 소요시간 6.83분
# 진행률 73.51%, 현재 소요시간 6.84분
# 진행률 73.64%, 현재 소요시간 6.85분
# 진행률 73.77%, 현재 소요시간 6.86분
# 진행률 73.9%, 현재 소요시간 6.87분
# 진행률 74.03%, 현재 소요시간 6.88분
# 진행률 74.16%, 현재 소요시간 6.89분
# 진행률 74.29%, 현재 소요시간 6.9분
# 진행률 74.42%, 현재 소요시간 6.91분
# 진행률 74.55%, 현재 소요시간 6.93분
# 진행률 74.68%, 현재 소요시간 6.94분
# 진행률 74.81%, 현재 소요시간 6.95분
# 진행률 74.94%, 현재 소요시간 6.96분
# 진행률 75.06%, 현재 소요시간 6.97분
# 진행률 75.19%, 현재 소요시간 6.98분
# 진행률 75.32%, 현재 소요시간 6.99분
# 진행률 75.45%, 현재 소요시간 7.0분
# 진행률 75.58%, 현재 소요시간 7.01분
# 진행률 75.71%, 현재 소요시간 7.03분
# 진행률 75.84%, 현재 소요시간 7.04분
# 진행률 75.97%, 현재 소요시간 7.05분
# 진행률 76.1%, 현재 소요시간 7.06분
# 진행률 76.23%, 현재 소요시간 7.07분
# 진행률 76.36%, 현재 소요시간 7.08분
# 진행률 76.49%, 현재 소요시간 7.09분
# 진행률 76.62%, 현재 소요시간 7.11분
# 진행률 76.75%, 현재 소요시간 7.12분
# 진행률 76.88%, 현재 소요시간 7.13분
# 진행률 77.01%, 현재 소요시간 7.14분
# 진행률 77.14%, 현재 소요시간 7.15분
# 진행률 77.26%, 현재 소요시간 7.16분
# 진행률 77.39%, 현재 소요시간 7.17분
# 진행률 77.52%, 현재 소요시간 7.18분
# 진행률 77.65%, 현재 소요시간 7.2분
# 진행률 77.78%, 현재 소요시간 7.21분
# 진행률 77.91%, 현재 소요시간 7.22분
# 진행률 78.04%, 현재 소요시간 7.23분
# 진행률 78.17%, 현재 소요시간 7.24분
# 진행률 78.3%, 현재 소요시간 7.25분
# 진행률 78.43%, 현재 소요시간 7.26분
# 진행률 78.56%, 현재 소요시간 7.27분
# 진행률 78.69%, 현재 소요시간 7.29분
# 진행률 78.82%, 현재 소요시간 7.3분
# 진행률 78.95%, 현재 소요시간 7.31분
# 진행률 79.08%, 현재 소요시간 7.32분
# 진행률 79.21%, 현재 소요시간 7.33분
# 진행률 79.34%, 현재 소요시간 7.34분
# 진행률 79.47%, 현재 소요시간 7.35분
# 진행률 79.59%, 현재 소요시간 7.36분
# 진행률 79.72%, 현재 소요시간 7.38분
# 진행률 79.85%, 현재 소요시간 7.39분
# 진행률 79.98%, 현재 소요시간 7.4분
# 진행률 80.11%, 현재 소요시간 7.41분
# 진행률 80.24%, 현재 소요시간 7.42분
# 진행률 80.37%, 현재 소요시간 7.43분
# 진행률 80.5%, 현재 소요시간 7.44분
# 진행률 80.63%, 현재 소요시간 7.46분
# 진행률 80.76%, 현재 소요시간 7.47분
# 진행률 80.89%, 현재 소요시간 7.48분
# 진행률 81.02%, 현재 소요시간 7.49분
# 진행률 81.15%, 현재 소요시간 7.5분
# 진행률 81.28%, 현재 소요시간 7.51분
# 진행률 81.41%, 현재 소요시간 7.53분
# 진행률 81.54%, 현재 소요시간 7.54분
# 진행률 81.67%, 현재 소요시간 7.55분
# 진행률 81.79%, 현재 소요시간 7.56분
# 진행률 81.92%, 현재 소요시간 7.57분
# 진행률 82.05%, 현재 소요시간 7.58분
# 진행률 82.18%, 현재 소요시간 7.6분
# 진행률 82.31%, 현재 소요시간 7.61분
# 진행률 82.44%, 현재 소요시간 7.62분
# 진행률 82.57%, 현재 소요시간 7.63분
# 진행률 82.7%, 현재 소요시간 7.64분
# 진행률 82.83%, 현재 소요시간 7.66분
# 진행률 82.96%, 현재 소요시간 7.67분
# 진행률 83.09%, 현재 소요시간 7.68분
# 진행률 83.22%, 현재 소요시간 7.69분
# 진행률 83.35%, 현재 소요시간 7.7분
# 진행률 83.48%, 현재 소요시간 7.72분
# 진행률 83.61%, 현재 소요시간 7.73분
# 진행률 83.74%, 현재 소요시간 7.74분
# 진행률 83.87%, 현재 소요시간 7.75분
# 진행률 83.99%, 현재 소요시간 7.76분
# 진행률 84.12%, 현재 소요시간 7.78분
# 진행률 84.25%, 현재 소요시간 7.79분
# 진행률 84.38%, 현재 소요시간 7.8분
# 진행률 84.51%, 현재 소요시간 7.81분
# 진행률 84.64%, 현재 소요시간 7.82분
# 진행률 84.77%, 현재 소요시간 7.84분
# 진행률 84.9%, 현재 소요시간 7.85분
# 진행률 85.03%, 현재 소요시간 7.86분
# 진행률 85.16%, 현재 소요시간 7.87분
# 진행률 85.29%, 현재 소요시간 7.89분
# 진행률 85.42%, 현재 소요시간 7.9분
# 진행률 85.55%, 현재 소요시간 7.91분
# 진행률 85.68%, 현재 소요시간 7.92분
# 진행률 85.81%, 현재 소요시간 7.93분
# 진행률 85.94%, 현재 소요시간 7.94분
# 진행률 86.07%, 현재 소요시간 7.96분
# 진행률 86.19%, 현재 소요시간 7.97분
# 진행률 86.32%, 현재 소요시간 7.98분
# 진행률 86.45%, 현재 소요시간 7.99분
# 진행률 86.58%, 현재 소요시간 8.0분
# 진행률 86.71%, 현재 소요시간 8.01분
# 진행률 86.84%, 현재 소요시간 8.03분
# 진행률 86.97%, 현재 소요시간 8.04분
# 진행률 87.1%, 현재 소요시간 8.05분
# 진행률 87.23%, 현재 소요시간 8.06분
# 진행률 87.36%, 현재 소요시간 8.07분
# 진행률 87.49%, 현재 소요시간 8.09분
# 진행률 87.62%, 현재 소요시간 8.1분
# 진행률 87.75%, 현재 소요시간 8.11분
# 진행률 87.88%, 현재 소요시간 8.12분
# 진행률 88.01%, 현재 소요시간 8.13분
# 진행률 88.14%, 현재 소요시간 8.14분
# 진행률 88.27%, 현재 소요시간 8.15분
# 진행률 88.4%, 현재 소요시간 8.16분
# 진행률 88.52%, 현재 소요시간 8.17분
# 진행률 88.65%, 현재 소요시간 8.18분
# 진행률 88.78%, 현재 소요시간 8.2분
# 진행률 88.91%, 현재 소요시간 8.21분
# 진행률 89.04%, 현재 소요시간 8.22분
# 진행률 89.17%, 현재 소요시간 8.23분
# 진행률 89.3%, 현재 소요시간 8.24분
# 진행률 89.43%, 현재 소요시간 8.25분
# 진행률 89.56%, 현재 소요시간 8.26분
# 진행률 89.69%, 현재 소요시간 8.27분
# 진행률 89.82%, 현재 소요시간 8.29분
# 진행률 89.95%, 현재 소요시간 8.3분
# 진행률 90.08%, 현재 소요시간 8.31분
# 진행률 90.21%, 현재 소요시간 8.32분
# 진행률 90.34%, 현재 소요시간 8.33분
# 진행률 90.47%, 현재 소요시간 8.34분
# 진행률 90.6%, 현재 소요시간 8.35분
# 진행률 90.72%, 현재 소요시간 8.36분
# 진행률 90.85%, 현재 소요시간 8.37분
# 진행률 90.98%, 현재 소요시간 8.39분
# 진행률 91.11%, 현재 소요시간 8.4분
# 진행률 91.24%, 현재 소요시간 8.41분
# 진행률 91.37%, 현재 소요시간 8.42분
# 진행률 91.5%, 현재 소요시간 8.43분
# 진행률 91.63%, 현재 소요시간 8.44분
# 진행률 91.76%, 현재 소요시간 8.45분
# 진행률 91.89%, 현재 소요시간 8.46분
# 진행률 92.02%, 현재 소요시간 8.48분
# 진행률 92.15%, 현재 소요시간 8.49분
# 진행률 92.28%, 현재 소요시간 8.5분
# 진행률 92.41%, 현재 소요시간 8.51분
# 진행률 92.54%, 현재 소요시간 8.52분
# 진행률 92.67%, 현재 소요시간 8.53분
# 진행률 92.8%, 현재 소요시간 8.54분
# 진행률 92.92%, 현재 소요시간 8.55분
# 진행률 93.05%, 현재 소요시간 8.57분
# 진행률 93.18%, 현재 소요시간 8.58분
# 진행률 93.31%, 현재 소요시간 8.59분
# 진행률 93.44%, 현재 소요시간 8.6분
# 진행률 93.57%, 현재 소요시간 8.61분
# 진행률 93.7%, 현재 소요시간 8.62분
# 진행률 93.83%, 현재 소요시간 8.63분
# 진행률 93.96%, 현재 소요시간 8.64분
# 진행률 94.09%, 현재 소요시간 8.66분
# 진행률 94.22%, 현재 소요시간 8.67분
# 진행률 94.35%, 현재 소요시간 8.68분
# 진행률 94.48%, 현재 소요시간 8.69분
# 진행률 94.61%, 현재 소요시간 8.7분
# 진행률 94.74%, 현재 소요시간 8.71분
# 진행률 94.87%, 현재 소요시간 8.72분
# 진행률 95.0%, 현재 소요시간 8.74분
# 진행률 95.13%, 현재 소요시간 8.75분
# 진행률 95.25%, 현재 소요시간 8.76분
# 진행률 95.38%, 현재 소요시간 8.77분
# 진행률 95.51%, 현재 소요시간 8.78분
# 진행률 95.64%, 현재 소요시간 8.79분
# 진행률 95.77%, 현재 소요시간 8.8분
# 진행률 95.9%, 현재 소요시간 8.81분
# 진행률 96.03%, 현재 소요시간 8.83분
# 진행률 96.16%, 현재 소요시간 8.84분
# 진행률 96.29%, 현재 소요시간 8.85분
# 진행률 96.42%, 현재 소요시간 8.86분
# 진행률 96.55%, 현재 소요시간 8.87분
# 진행률 96.68%, 현재 소요시간 8.88분
# 진행률 96.81%, 현재 소요시간 8.89분
# 진행률 96.94%, 현재 소요시간 8.9분
# 진행률 97.07%, 현재 소요시간 8.92분
# 진행률 97.2%, 현재 소요시간 8.93분
# 진행률 97.33%, 현재 소요시간 8.94분
# 진행률 97.45%, 현재 소요시간 8.95분
# 진행률 97.58%, 현재 소요시간 8.96분
# 진행률 97.71%, 현재 소요시간 8.97분
# 진행률 97.84%, 현재 소요시간 8.98분
# 진행률 97.97%, 현재 소요시간 9.0분
# 진행률 98.1%, 현재 소요시간 9.01분
# 진행률 98.23%, 현재 소요시간 9.02분
# 진행률 98.36%, 현재 소요시간 9.03분
# 진행률 98.49%, 현재 소요시간 9.04분
# 진행률 98.62%, 현재 소요시간 9.05분
# 진행률 98.75%, 현재 소요시간 9.07분
# 진행률 98.88%, 현재 소요시간 9.08분
# 진행률 99.01%, 현재 소요시간 9.09분
# 진행률 99.14%, 현재 소요시간 9.1분
# 진행률 99.27%, 현재 소요시간 9.11분
# 진행률 99.4%, 현재 소요시간 9.12분
# 진행률 99.53%, 현재 소요시간 9.14분
# 진행률 99.65%, 현재 소요시간 9.15분
# 진행률 99.78%, 현재 소요시간 9.16분
# 진행률 99.91%, 현재 소요시간 9.17분

# %%
order = stra.get_order_for_exe(company_num=10, capital=200000000, trade_day='20200221')
order.to_pickle('../Database/order{}.pickle'.format(stra.today))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 1582243200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-9b83586ac548> in <module>
# ----> 1 order = stra.get_order_for_exe(company_num=10, capital=200000000, trade_day='20200221')
#       2 order.to_pickle('../Database/order{}.pickle'.format(stra.today))
#
# ~\PycharmProjects\finance\strategy_ma.py in get_order_for_exe(self, company_num, capital, trade_day)
#     125         short_codes = list(self.result['short_code'].iloc[:company_num])
#     126         codenames = list(self.result['codeName'].iloc[:company_num])
# --> 127         prices = self.price_data[self.price_data['short_code'].isin(short_codes)].loc[trade_day][
#     128             'close']  ## 12시 전에 돌리면 today고 아니면 today-timedelta(days=1)
#     129         print(short_codes)
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#    1037             else:
#    1038                 key = Timestamp(key).tz_convert(self.tz)
# -> 1039             return Index.get_loc(self, key, method, tolerance)
#    1040
#    1041         elif isinstance(key, timedelta):
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 1582243200000000000

# %% [markdown]
# # 여기서부터는 32BIT 환경
