# %%
from strategy_ma import strategy_ma

# %%
decider = strategy_ma()

# %%
adj_total = decider.adj_total
adj_total
# Out:
#           date      adj short_code
# 0   2020-01-20   2880.0    A060310
# 1   2020-01-17   2930.0    A060310
# 2   2020-01-16   2905.0    A060310
# 3   2020-01-15   2800.0    A060310
# 4   2020-01-14   2805.0    A060310
# ..         ...      ...        ...
# 518 2018-01-26  24050.0    A238490
# 519 2018-01-25  23050.0    A238490
# 520 2018-01-24  22950.0    A238490
# 521 2018-01-23  23200.0    A238490
# 522 2018-01-22  22900.0    A238490
#
# [1099879 rows x 3 columns]

# %%
full_code = decider.full_code
full_code
# Out:
#          full_code short_code codeName marketName
# 0     KR7079940003    A079940      가비아     KOSDAQ
# 1     KR7078890001    A078890    가온미디어     KOSDAQ
# 2     KR7000500009    A000500     가온전선      KOSPI
# 3     KR7192410009    A192410      감마누     KOSDAQ
# 4     KR7000860007    A000860   강남제비스코      KOSPI
# ...            ...        ...      ...        ...
# 2545  KR7057030009    A057030     YBM넷     KOSDAQ
# 2546  KR7037270006    A037270  YG PLUS      KOSPI
# 2547  KR7040300006    A040300      YTN     KOSDAQ
# 2548  KR7051390003    A051390       YW     KOSDAQ
# 2549  KR7052220001    A052220     iMBC     KOSDAQ
#
# [2550 rows x 4 columns]

# %%
price_dic = dict()
for idx, short_code in enumerate(full_code['short_code']):
    price_of_name = adj_total[adj_total['short_code'] == short_code].copy()
    price_dic[short_code] = price_of_name
    print('남은 개수 : {}'.format(len(full_code['short_code']) - idx))
# Out:
# 남은 개수 : 2550
# 남은 개수 : 2549
# 남은 개수 : 2548
# 남은 개수 : 2547
# 남은 개수 : 2546
# 남은 개수 : 2545
# 남은 개수 : 2544
# 남은 개수 : 2543
# 남은 개수 : 2542
# 남은 개수 : 2541
# 남은 개수 : 2540
# 남은 개수 : 2539
# 남은 개수 : 2538
# 남은 개수 : 2537
# 남은 개수 : 2536
# 남은 개수 : 2535
# 남은 개수 : 2534
# 남은 개수 : 2533
# 남은 개수 : 2532
# 남은 개수 : 2531
# 남은 개수 : 2530
# 남은 개수 : 2529
# 남은 개수 : 2528
# 남은 개수 : 2527
# 남은 개수 : 2526
# 남은 개수 : 2525
# 남은 개수 : 2524
# 남은 개수 : 2523
# 남은 개수 : 2522
# 남은 개수 : 2521
# 남은 개수 : 2520
# 남은 개수 : 2519
# 남은 개수 : 2518
# 남은 개수 : 2517
# 남은 개수 : 2516
# 남은 개수 : 2515
# 남은 개수 : 2514
# 남은 개수 : 2513
# 남은 개수 : 2512
# 남은 개수 : 2511
# 남은 개수 : 2510
# 남은 개수 : 2509
# 남은 개수 : 2508
# 남은 개수 : 2507
# 남은 개수 : 2506
# 남은 개수 : 2505
# 남은 개수 : 2504
# 남은 개수 : 2503
# 남은 개수 : 2502
# 남은 개수 : 2501
# 남은 개수 : 2500
# 남은 개수 : 2499
# 남은 개수 : 2498
# 남은 개수 : 2497
# 남은 개수 : 2496
# 남은 개수 : 2495
# 남은 개수 : 2494
# 남은 개수 : 2493
# 남은 개수 : 2492
# 남은 개수 : 2491
# 남은 개수 : 2490
# 남은 개수 : 2489
# 남은 개수 : 2488
# 남은 개수 : 2487
# 남은 개수 : 2486
# 남은 개수 : 2485
# ...

# %%
price_dic['A005930']
# Out:
#           date      adj short_code
# 0   2020-01-20  62400.0    A005930
# 1   2020-01-19  61300.0    A005930
# 2   2020-01-17  61300.0    A005930
# 3   2020-01-16  60700.0    A005930
# 4   2020-01-15  59000.0    A005930
# ..         ...      ...        ...
# 547 2018-01-26  50780.0    A005930
# 548 2018-01-25  50260.0    A005930
# 549 2018-01-24  49340.0    A005930
# 550 2018-01-23  49160.0    A005930
# 551 2018-01-22  48240.0    A005930
#
# [552 rows x 3 columns]

# %%
from yahooreader import yahooreader

# %%
adj_pricer = yahooreader()

# %%
import pandas as pd

# %%
ten_year_price = []
for idx, short_code in enumerate(full_code['short_code']):
    try:
        codeName = full_code['codeName'].iloc[idx]
        data = adj_pricer.get_adj_close(short_code, '20100101', '20200101')
        if len(data) < 10:
            continue
        data['short_code'] = short_code
        data['codeName'] = codeName
        ten_year_price.append(data)
        print('남은 개수 : {}'.format(len(full_code['short_code']) - idx))
    except Exception as e:
        print(e)
        print(short_code)

ten_year_price_df = pd.concat(ten_year_price)
ten_year_price_df.to_pickle('ten_year_price.pickle')
# Out:
# 스크롤 시작
# A079940종목 크롤링 개수 부족
# A079940종목 크롤링 개수 부족
# 스크롤 시작
# A078890종목 크롤링 개수 부족
# A078890종목 크롤링 개수 부족
# 스크롤 시작
# 남은 개수 : 2548
# 스크롤 시작
# A192410종목 크롤링 개수 부족
# A192410종목 크롤링 개수 부족
# 스크롤 시작
# 남은 개수 : 2546
# 스크롤 시작
# A217730종목 크롤링 개수 부족
# A217730종목 크롤링 개수 부족
# 스크롤 시작
# A114190종목 크롤링 개수 부족
# A114190종목 크롤링 개수 부족
# 스크롤 시작
# 남은 개수 : 2543
# 스크롤 시작
# 남은 개수 : 2542
# 스크롤 시작
# A094480종목 크롤링 개수 부족
# A094480종목 크롤링 개수 부족
# 스크롤 시작
# A063080종목 크롤링 개수 부족
# A063080종목 크롤링 개수 부족
# 스크롤 시작
# A039240종목 크롤링 개수 부족
# A039240종목 크롤링 개수 부족
# 스크롤 시작
# A053950종목 크롤링 개수 부족
# A053950종목 크롤링 개수 부족
# 스크롤 시작
# 남은 개수 : 2537
# 스크롤 시작
# 남은 개수 : 2536
# 스크롤 시작
# A267290종목 크롤링 개수 부족
# A267290종목 크롤링 개수 부족
# 남은 개수 : 2535
# 스크롤 시작
# 남은 개수 : 2534
# 스크롤 시작
# A011040종목 크롤링 개수 부족
# A011040종목 크롤링 개수 부족
# 스크롤 시작
# 남은 개수 : 2532
# 스크롤 시작
# A214390종목 크롤링 개수 부족
# A214390종목 크롤링 개수 부족
# 남은 개수 : 2531
# 스크롤 시작
# 남은 개수 : 2530
# 스크롤 시작
# 남은 개수 : 2529
# 스크롤 시작
# A024910종목 크롤링 개수 부족
# A024910종목 크롤링 개수 부족
# 스크롤 시작
# 남은 개수 : 2527
# 스크롤 시작
# ...

# %%
from investingreader import investingreader

# %%
import pandas as pd

# %%
pricer = investingreader()

# %%
samsung = pricer.get_adj_price('A005930', '20150101', '20200101')

# %%
samsung
# Out:
#               Date    Price     Open     High      Low     Vol. Change %
# 0     Dec 30, 2019    55800    56200    56600    55700    8.35M   -1.24%
# 1     Dec 29, 2019    56500    56500    56500    56500        -    0.00%
# 2     Dec 27, 2019    56500    55700    56900    55500   12.29M    1.99%
# 3     Dec 26, 2019    55400    54800    55400    54400    5.92K    0.73%
# 4     Dec 25, 2019    55000    55000    55000    55000        -    0.00%
# ...            ...      ...      ...      ...      ...      ...      ...
# 1380  Jan 07, 2015  1307000  1294000  1311000  1282000  283.40K    0.93%
# 1381  Jan 06, 2015  1295000  1315000  1317000  1288000  304.55K   -2.85%
# 1382  Jan 05, 2015  1333000  1336000  1336000  1313000  202.06K    0.23%
# 1383  Jan 04, 2015  1330000  1330000  1330000  1330000        -    0.00%
# 1384  Jan 02, 2015  1330000  1340000  1340000  1327000  159.97K    0.23%
#
# [1385 rows x 7 columns]

# %%
samsung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 7 columns):
# Date        1385 non-null object
# Price       1385 non-null int64
# Open        1385 non-null int64
# High        1385 non-null int64
# Low         1385 non-null int64
# Vol.        1385 non-null object
# Change %    1385 non-null object
# dtypes: int64(4), object(3)
# memory usage: 75.9+ KB

# %%
samsung['Date'] = pd.to_datetime(samsung['Date'])

# %%
samsung.index = samsung['Date']

# %%
samsung.index.name = 'date'

# %%
samsung.drop(['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b1510b421412> in <module>
# ----> 1 samsung.drop(['Date'])
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~\Anaconda3\envs\finance64\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
del samsung['Date']

# %%
samsung
# Out:
#               Price     Open     High      Low     Vol. Change %
# date
# 2019-12-30    55800    56200    56600    55700    8.35M   -1.24%
# 2019-12-29    56500    56500    56500    56500        -    0.00%
# 2019-12-27    56500    55700    56900    55500   12.29M    1.99%
# 2019-12-26    55400    54800    55400    54400    5.92K    0.73%
# 2019-12-25    55000    55000    55000    55000        -    0.00%
# ...             ...      ...      ...      ...      ...      ...
# 2015-01-07  1307000  1294000  1311000  1282000  283.40K    0.93%
# 2015-01-06  1295000  1315000  1317000  1288000  304.55K   -2.85%
# 2015-01-05  1333000  1336000  1336000  1313000  202.06K    0.23%
# 2015-01-04  1330000  1330000  1330000  1330000        -    0.00%
# 2015-01-02  1330000  1340000  1340000  1327000  159.97K    0.23%
#
# [1385 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(samsung['Price'].iloc[:650])
plt.show()

# %%
samsung[samsung['Price']>100000]
# Out:
#               Price     Open     High      Low     Vol.   Change %
# date
# 2017-10-09  2564000  2564000  2564000  2564000    0.01K  4,900.00%
# 2017-06-06  2297000  2297000  2297000  2297000        -  4,900.00%
# 2017-05-09  2351000  2351000  2351000  2351000    0.04K  4,900.00%
# 2017-05-03  2245000  2245000  2245000  2245000        -  4,900.00%
# 2017-05-01  2231000  2231000  2231000  2231000    0.00K  4,900.00%
# ...             ...      ...      ...      ...      ...        ...
# 2015-01-07  1307000  1294000  1311000  1282000  283.40K      0.93%
# 2015-01-06  1295000  1315000  1317000  1288000  304.55K     -2.85%
# 2015-01-05  1333000  1336000  1336000  1313000  202.06K      0.23%
# 2015-01-04  1330000  1330000  1330000  1330000        -      0.00%
# 2015-01-02  1330000  1340000  1340000  1327000  159.97K      0.23%
#
# [414 rows x 6 columns]

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
from finance_util import seq_mul
from bs4 import BeautifulSoup as bs
from krxpricereader import krxpricereader as prc
import numpy as np

def cum_mul(series):
    result = series.copy()
    for i in range(len(series)):
        result.iloc[i] = seq_mul(series.values[:i+1])
    return result

def read_xml(xml):
    soup = bs(xml,'lxml')   
    column = []
    for tag in soup.find('result').findAll(True):
        column.append(str(tag.name))

    df = pd.DataFrame(index = range(len(soup.findAll('result'))), columns = column)

    for i, result in enumerate(soup.findAll('result')):
        for j, col in enumerate(column):
            df.iloc[i,j] = result.find(col)['value']      

    return df

url = 'http://www.seibro.or.kr/websquare/engine/proworks/callServletService.jsp'

header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Accept': 'application/xml',
    'Referer': 'http://www.seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/company/BIP_CNTS01021V.xml'
}

payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="divStatInfoPList" task="ksd.safe.bip.cnts.Company.process.EntrFnafInfoPTask"><RGT_STD_DT_FROM value="20190208"/><RGT_STD_DT_TO value="20200208"/><ISSUCO_CUSTNO value="593"/><KOR_SECN_NM value=""/><SECN_KACD value=""/><RGT_RSN_DTAIL_SORT_CD value=""/><LIST_TPCD value=""/><START_PAGE value="1"/><END_PAGE value="15"/><MENU_NO value="285"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01041V.xml"/></reqParam>'
payload2 = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="termByImptSkedulList" task="ksd.safe.bip.cnts.Company.process.EntrSkedulPTask"><MENU_NO value="274"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01021V.xml"/><ISSUCO_CUSTNO value="593"/><DT_TPCD value=""/><FROMDATE value="20190209"/><TODATE value="20200208"/><LIST_TPCD value=""/><RGT_RACD value=""/></reqParam>'

fromdate = '20190101'
todate = '20200101'
cust_no = '593'

div_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="divStatInfoPList" task="ksd.safe.bip.cnts.Company.process.EntrFnafInfoPTask"><RGT_STD_DT_FROM value="{0}"/><RGT_STD_DT_TO value="{1}"/><ISSUCO_CUSTNO value="{2}"/><KOR_SECN_NM value=""/><SECN_KACD value=""/><RGT_RSN_DTAIL_SORT_CD value=""/><LIST_TPCD value=""/><START_PAGE value="1"/><END_PAGE value="15"/><MENU_NO value="285"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01041V.xml"/></reqParam>'.format(fromdate, todate, cust_no)
schd_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="termByImptSkedulList" task="ksd.safe.bip.cnts.Company.process.EntrSkedulPTask"><MENU_NO value="274"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01021V.xml"/><ISSUCO_CUSTNO value="{0}"/><DT_TPCD value=""/><FROMDATE value="{1}"/><TODATE value="{2}"/><LIST_TPCD value=""/><RGT_RACD value=""/></reqParam>'.format(cust_no, fromdate, todate)

pricer = prc()
sam = pricer.get_stock_price('A005930', '20190101', '20200101')

r = requests.post(url, data=div_payload, headers=header).text
r2 = requests.post(url, data=schd_payload, headers=header).text

div_info = read_xml(r)
schedule = read_xml(r2)


b = schedule[schedule['rgt_ranm'] == '배당/분배'].copy()
b = b[b['dt_tpnm'] == '권리락일']
b = b[['issuco_custno','rgt_ranm','rgt_std_dt','dt_expry_dt']]
a = div_info[div_info['kor_secn_nm'] == '삼성전자'][['rgt_std_dt','shotn_isin', 'kor_secn_nm', 'cash_aloc_amt']].copy()


cash_amt = []
for idx,std_dt in enumerate(b['rgt_std_dt']):
    cash = a[a['rgt_std_dt'] == std_dt]['cash_aloc_amt'].iloc[0]
    cash_amt.append(cash)
b['cash_aloc_amt'] = cash_amt


b.index = pd.to_datetime(b['dt_expry_dt'])
b['cash_aloc_amt'] = b['cash_aloc_amt'].apply(lambda x :int(x))
b.index.name = 'date'

sam['div'] = 0
sam1 = sam.copy()
for date in b.index:
    sam1['div'].loc[date] = b['cash_aloc_amt'].loc[date]

x = 1 - sam1['div'] / (sam1['tdd_clsprc'] - sam1['div'])
x

sam1[['mktcap', 'list_shrs']] = sam1[['mktcap', 'list_shrs']].applymap(lambda x: int(x.replace(',','')))

divider = sam1['list_shrs'].iloc[0]
cls = sam1['mktcap'] / divider * 1000000
cls = cls.apply(lambda x : int(round(x,0)))

adj = cls * cum_mul(x)
adj

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
from finance_util import seq_mul
from bs4 import BeautifulSoup as bs
from krxpricereader import krxpricereader as prc
import numpy as np

# %%
def cum_mul(series):
    result = series.copy()
    for i in range(len(series)):
        result.iloc[i] = seq_mul(series.values[:i+1])
    return result

# %%
def read_xml(xml):
    soup = bs(xml,'lxml')   
    column = []
    for tag in soup.find('result').findAll(True):
        column.append(str(tag.name))

    df = pd.DataFrame(index = range(len(soup.findAll('result'))), columns = column)

    for i, result in enumerate(soup.findAll('result')):
        for j, col in enumerate(column):
            df.iloc[i,j] = result.find(col)['value']      

    return df

# %%
url = 'http://www.seibro.or.kr/websquare/engine/proworks/callServletService.jsp'

# %%
header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'Accept': 'application/xml',
    'Referer': 'http://www.seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/company/BIP_CNTS01021V.xml'
}

# %%
payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="divStatInfoPList" task="ksd.safe.bip.cnts.Company.process.EntrFnafInfoPTask"><RGT_STD_DT_FROM value="20190208"/><RGT_STD_DT_TO value="20200208"/><ISSUCO_CUSTNO value="593"/><KOR_SECN_NM value=""/><SECN_KACD value=""/><RGT_RSN_DTAIL_SORT_CD value=""/><LIST_TPCD value=""/><START_PAGE value="1"/><END_PAGE value="15"/><MENU_NO value="285"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01041V.xml"/></reqParam>'
payload2 = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="termByImptSkedulList" task="ksd.safe.bip.cnts.Company.process.EntrSkedulPTask"><MENU_NO value="274"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01021V.xml"/><ISSUCO_CUSTNO value="593"/><DT_TPCD value=""/><FROMDATE value="20190209"/><TODATE value="20200208"/><LIST_TPCD value=""/><RGT_RACD value=""/></reqParam>'

# %%
fromdate = '20190101'
todate = '20200101'
cust_no = '593'

# %%
div_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="divStatInfoPList" task="ksd.safe.bip.cnts.Company.process.EntrFnafInfoPTask"><RGT_STD_DT_FROM value="{0}"/><RGT_STD_DT_TO value="{1}"/><ISSUCO_CUSTNO value="{2}"/><KOR_SECN_NM value=""/><SECN_KACD value=""/><RGT_RSN_DTAIL_SORT_CD value=""/><LIST_TPCD value=""/><START_PAGE value="1"/><END_PAGE value="15"/><MENU_NO value="285"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01041V.xml"/></reqParam>'.format(fromdate, todate, cust_no)
schd_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="termByImptSkedulList" task="ksd.safe.bip.cnts.Company.process.EntrSkedulPTask"><MENU_NO value="274"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01021V.xml"/><ISSUCO_CUSTNO value="{0}"/><DT_TPCD value=""/><FROMDATE value="{1}"/><TODATE value="{2}"/><LIST_TPCD value=""/><RGT_RACD value=""/></reqParam>'.format(cust_no, fromdate, todate)

# %%
pricer = prc()
sam = pricer.get_stock_price('A005930', '20190101', '20200101')

r = requests.post(url, data=div_payload, headers=header).text
r2 = requests.post(url, data=schd_payload, headers=header).text

div_info = read_xml(r)
schedule = read_xml(r2)


b = schedule[schedule['rgt_ranm'] == '배당/분배'].copy()
b = b[b['dt_tpnm'] == '권리락일']
b = b[['issuco_custno','rgt_ranm','rgt_std_dt','dt_expry_dt']]
a = div_info[div_info['kor_secn_nm'] == '삼성전자'][['rgt_std_dt','shotn_isin', 'kor_secn_nm', 'cash_aloc_amt']].copy()


cash_amt = []
for idx,std_dt in enumerate(b['rgt_std_dt']):
    cash = a[a['rgt_std_dt'] == std_dt]['cash_aloc_amt'].iloc[0]
    cash_amt.append(cash)
b['cash_aloc_amt'] = cash_amt


b.index = pd.to_datetime(b['dt_expry_dt'])
b['cash_aloc_amt'] = b['cash_aloc_amt'].apply(lambda x :int(x))
b.index.name = 'date'

sam['div'] = 0
sam1 = sam.copy()
for date in b.index:
    sam1['div'].loc[date] = b['cash_aloc_amt'].loc[date]

x = 1 - sam1['div'] / (sam1['tdd_clsprc'] - sam1['div'])
x

sam1[['mktcap', 'list_shrs']] = sam1[['mktcap', 'list_shrs']].applymap(lambda x: int(x.replace(',','')))

divider = sam1['list_shrs'].iloc[0]
cls = sam1['mktcap'] / divider * 1000000
cls = cls.apply(lambda x : int(round(x,0)))

adj = cls * cum_mul(x)
adj

# %%
xml = requests.post(url, data = payload3.format(11), headers=header).text
kospi_code = read_xml(xml)

kospi_code[kospi_code['kor_secn_nm'] == '삼성전자']

mkt_num = ['11','12','14']
sum_list = []
for mkt in mkt_num:
    payload = payload3.format(mkt)
    xml = requests.post(url, data = payload, headers=header).text
    sum_list.append(read_xml(xml))
total = pd.concat(sum_list)

total

total.to_pickle('../Database/seibro_code.pickle')

# %%
total
# Out:
#              isin issuco_custno kor_secn_nm shotn_isin codevalue_nm
# 0    KR7138930003         16920     BNK금융지주     138930          (유)
# 1    KR7001460005           146         BYC     001460          (유)
# 2    KR7001461003           146       BYC1우     001465          (유)
# 3    KR7011150000          1115       CJ씨푸드     011150          (유)
# 4    KR7011151008          1115     CJ씨푸드1우     011155          (유)
# ..            ...           ...         ...        ...          ...
# 146  KR7242350007         27411     피엔아이컴퍼니     242350          (넥)
# 147  KR7239890007         27885     피엔에이치테크     239890          (넥)
# 148  KR7107640005         14546      한중엔시에스     107640          (넥)
# 149  KR7284420007         31616          휴럼     284420          (넥)
# 150  KR7212310007         24472         휴벡셀     212310          (넥)
#
# [2475 rows x 5 columns]

# %%
short_code = 'A005930'

# %%
total[total['shotn_isin'] == short_code[1:]]['issuco_custno'].iloc[0]
# Out:
# '593'

# %%
r = requests.post(url, data=payload, headers=header).text
r2 = requests.post(url, data=payload2, headers=header).text

# %%
div_info = read_xml(r)
schedule = read_xml(r2)

# %%
schedule.head()
# Out:
#          sch_dttm dt_begin_dt issuco_custno shotn_cd_issuin_no issuco_nm  \
# 0  20200209002902    20190305           593              00593      삼성전자
# 1  20200209002902    20190320           593              00593      삼성전자
# 2  20200209002902    20190328           593              00593      삼성전자
# 3  20200209002902    20190331           593              00593      삼성전자
# 4  20200209002902    20190401           593              00593      삼성전자
#
#   rgt_racd rgt_ranm rgt_rsn_dtail_sort_cd rgt_racd_nm_detail rgt_std_dt  \
# 0      001     정기총회                     N               정기총회   20181231
# 1      001     정기총회                     N               정기총회   20181231
# 2      103    배당/분배                    02        배당/분배(현금배당)   20190331
# 3      103    배당/분배                    02        배당/분배(현금배당)   20190331
# 4      103    배당/분배                    02        배당/분배(현금배당)   20190331
#
#   dt_tpcd dt_tpnm dt_expry_dt list_tpcd list_tpnm ag_org_tpcd ag_org_tpnm  \
# ...

# %%
b = schedule[schedule['rgt_ranm'] == '배당/분배'].copy()
b = b[b['dt_tpnm'] == '권리락일']
b = b[['issuco_custno','rgt_ranm','rgt_std_dt','dt_expry_dt']]
b
# Out:
#    issuco_custno rgt_ranm rgt_std_dt dt_expry_dt
# 2            593    배당/분배   20190331    20190328
# 9            593    배당/분배   20190630    20190627
# 17           593    배당/분배   20190930    20190927
# 23           593    배당/분배   20191231    20191227

# %%
a = div_info[div_info['kor_secn_nm'] == '삼성전자'][['rgt_std_dt','shotn_isin', 'kor_secn_nm', 'cash_aloc_amt']].copy()
a
# Out:
#   rgt_std_dt shotn_isin kor_secn_nm cash_aloc_amt
# 0   20191231     005930        삼성전자           354
# 2   20190930     005930        삼성전자           354
# 4   20190630     005930        삼성전자           354
# 6   20190331     005930        삼성전자           354

# %%
cash_amt = []
for idx,std_dt in enumerate(b['rgt_std_dt']):
    cash = a[a['rgt_std_dt'] == std_dt]['cash_aloc_amt'].iloc[0]
    cash_amt.append(cash)
b['cash_aloc_amt'] = cash_amt
b
# Out:
#    issuco_custno rgt_ranm rgt_std_dt dt_expry_dt cash_aloc_amt
# 2            593    배당/분배   20190331    20190328           354
# 9            593    배당/분배   20190630    20190627           354
# 17           593    배당/분배   20190930    20190927           354
# 23           593    배당/분배   20191231    20191227           354

# %%
b.index = pd.to_datetime(b['dt_expry_dt'])
b['cash_aloc_amt'] = b['cash_aloc_amt'].apply(lambda x :int(x))
b.index.name = 'date'
b
# Out:
#            issuco_custno rgt_ranm rgt_std_dt dt_expry_dt  cash_aloc_amt
# date
# 2019-03-28           593    배당/분배   20190331    20190328            354
# 2019-06-27           593    배당/분배   20190630    20190627            354
# 2019-09-27           593    배당/분배   20190930    20190927            354
# 2019-12-27           593    배당/분배   20191231    20191227            354

# %%
sam.head()
# Out:
#             tdd_clsprc fluc_tp tdd_cmpr  acc_trdvol       acc_trdval  \
# trd_dd
# 2019-12-30       55800       2      700   8,356,767  467,929,804,000
# 2019-12-27       56500       1    1,100  12,313,056  692,415,134,500
# 2019-12-26       55400       1      400   9,645,034  530,104,740,900
# 2019-12-24       55000       2      500  11,868,463  655,144,129,100
# 2019-12-23       55500       2      500   9,839,252  546,622,686,828
#
#            tdd_opnprc tdd_hgprc tdd_lwprc       mktcap      list_shrs  \
# trd_dd
# 2019-12-30     56,200    56,600    55,700  333,113,866  5,969,782,550
# 2019-12-27     55,700    56,900    55,500  337,292,714  5,969,782,550
# 2019-12-26     54,700    55,400    54,400  330,725,953  5,969,782,550
# 2019-12-24     55,600    55,700    54,800  328,338,040  5,969,782,550
# 2019-12-23     56,100    56,400    55,100  331,322,932  5,969,782,550
#
#            short_code codeName
# trd_dd
# 2019-12-30    A005930     삼성전자
# 2019-12-27    A005930     삼성전자
# ...

# %%
sam['div'] = 0
sam
# Out:
#             tdd_clsprc fluc_tp tdd_cmpr  acc_trdvol       acc_trdval  \
# trd_dd
# 2019-12-30       55800       2      700   8,356,767  467,929,804,000
# 2019-12-27       56500       1    1,100  12,313,056  692,415,134,500
# 2019-12-26       55400       1      400   9,645,034  530,104,740,900
# 2019-12-24       55000       2      500  11,868,463  655,144,129,100
# 2019-12-23       55500       2      500   9,839,252  546,622,686,828
# ...                ...     ...      ...         ...              ...
# 2019-01-08       38100       2      650  12,756,554  491,578,269,750
# 2019-01-07       38750       1    1,300  12,748,997  490,833,164,150
# 2019-01-04       37450       2      150  14,108,958  525,403,005,097
# 2019-01-03       37600       2    1,150  12,471,493  472,966,535,350
# 2019-01-02       38750       1       50   7,847,664  304,682,623,050
#
#            tdd_opnprc tdd_hgprc tdd_lwprc       mktcap      list_shrs  \
# trd_dd
# ...

# %%
sam1 = sam.copy()
for date in b.index:
    sam1['div'].loc[date] = b['cash_aloc_amt'].loc[date]

sam1
# Out:
#             tdd_clsprc fluc_tp tdd_cmpr  acc_trdvol       acc_trdval  \
# trd_dd
# 2019-12-30       55800       2      700   8,356,767  467,929,804,000
# 2019-12-27       56500       1    1,100  12,313,056  692,415,134,500
# 2019-12-26       55400       1      400   9,645,034  530,104,740,900
# 2019-12-24       55000       2      500  11,868,463  655,144,129,100
# 2019-12-23       55500       2      500   9,839,252  546,622,686,828
# ...                ...     ...      ...         ...              ...
# 2019-01-08       38100       2      650  12,756,554  491,578,269,750
# 2019-01-07       38750       1    1,300  12,748,997  490,833,164,150
# 2019-01-04       37450       2      150  14,108,958  525,403,005,097
# 2019-01-03       37600       2    1,150  12,471,493  472,966,535,350
# 2019-01-02       38750       1       50   7,847,664  304,682,623,050
#
#            tdd_opnprc tdd_hgprc tdd_lwprc       mktcap      list_shrs  \
# trd_dd
# ...

# %%
x = 1 - sam1['div'] / (sam1['tdd_clsprc'] - sam1['div'])
x
# Out:
# trd_dd
# 2019-12-30    1.000000
# 2019-12-27    0.993695
# 2019-12-26    1.000000
# 2019-12-24    1.000000
# 2019-12-23    1.000000
#                 ...
# 2019-01-08    1.000000
# 2019-01-07    1.000000
# 2019-01-04    1.000000
# 2019-01-03    1.000000
# 2019-01-02    1.000000
# Length: 246, dtype: float64

# %%
sam1[['mktcap', 'list_shrs']] = sam1[['mktcap', 'list_shrs']].applymap(lambda x: int(x.replace(',','')))

# %%
divider = sam1['list_shrs'].iloc[0]
cls = sam1['mktcap'] / divider * 1000000
cls = cls.apply(lambda x : int(round(x,0)))
cls
# Out:
# trd_dd
# 2019-12-30    55800
# 2019-12-27    56500
# 2019-12-26    55400
# 2019-12-24    55000
# 2019-12-23    55500
#               ...
# 2019-01-08    38100
# 2019-01-07    38750
# 2019-01-04    37450
# 2019-01-03    37600
# 2019-01-02    38750
# Name: mktcap, Length: 246, dtype: int64

# %%
def cum_mul(series):
    result = series.copy()
    for i in range(len(series)):
        result.iloc[i] = seq_mul(series.values[:i+1])
    return result

# %%
cum_mul(x)
# Out:
# trd_dd
# 2019-12-30    1.000000
# 2019-12-27    0.993695
# 2019-12-26    0.993695
# 2019-12-24    0.993695
# 2019-12-23    0.993695
#                 ...
# 2019-01-08    0.971020
# 2019-01-07    0.971020
# 2019-01-04    0.971020
# 2019-01-03    0.971020
# 2019-01-02    0.971020
# Length: 246, dtype: float64

# %%
adj = cls * cum_mul(x)
adj
# Out:
# trd_dd
# 2019-12-30    55800.000000
# 2019-12-27    56143.768033
# 2019-12-26    55050.703523
# 2019-12-24    54653.225519
# 2019-12-23    55150.073024
#                   ...
# 2019-01-08    36995.846424
# 2019-01-07    37627.009159
# 2019-01-04    36364.683690
# 2019-01-03    36510.336629
# 2019-01-02    37627.009159
# Length: 246, dtype: float64

# %%
plt.plot(adj)
plt.show()

# %%
plt.plot(sam['tdd_clsprc'])
plt.show()

# %%
import pandas as pd
import requests
from finance_util import seq_mul, cum_mul, read_xml
from krxpricereader import krxpricereader as prc
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

def get_adj_price(short_code, fromdate, todate):
    total = pd.read_pickle('../Database/seibro_code.pickle')
    cust_no = total[total['shotn_isin'] == short_code[1:]]['issuco_custno'].iloc[0]
    codeName = total[total['shotn_isin'] == short_code[1:]]['kor_secn_nm'].iloc[0]
    url = 'http://www.seibro.or.kr/websquare/engine/proworks/callServletService.jsp'

    header = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                      'Chrome/79.0.3945.130 Safari/537.36',
        'Accept': 'application/xml',
        'Referer': 'http://www.seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/company/BIP_CNTS01021V.xml'
    }

    
    schd_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="termByImptSkedulList" task="ksd.safe.bip.cnts.Company.process.EntrSkedulPTask"><MENU_NO value="274"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01021V.xml"/><ISSUCO_CUSTNO value="{0}"/><DT_TPCD value=""/><FROMDATE value="{1}"/><TODATE value="{2}"/><LIST_TPCD value=""/><RGT_RACD value=""/></reqParam>'.format(cust_no, fromdate, todate)
    pricer = prc()
    com = pricer.get_stock_price(short_code, fromdate, todate)
    r2 = requests.post(url, data=schd_payload, headers=header).text    
    schedule = read_xml(r2)
    
    
    fromdate_dt = pd.to_datetime(fromdate)
    todate_dt = pd.to_datetime(todate)
    bef_two_year = todate_dt - relativedelta(years=2) 
    
    div_info_list = []
    while True:
        if bef_two_year> fromdate_dt:
            fromdate_str = bef_two_year.strftime('%Y%m%d')
            todate_str = todate_dt.strftime('%Y%m%d')
            div_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="divStatInfoPList" task="ksd.safe.bip.cnts.Company.process.EntrFnafInfoPTask"><RGT_STD_DT_FROM value="{0}"/><RGT_STD_DT_TO value="{1}"/><ISSUCO_CUSTNO value="{2}"/><KOR_SECN_NM value=""/><SECN_KACD value=""/><RGT_RSN_DTAIL_SORT_CD value=""/><LIST_TPCD value=""/><START_PAGE value="1"/><END_PAGE value="15"/><MENU_NO value="285"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01041V.xml"/></reqParam>'.format(fromdate_str, todate_str, cust_no)
            r1 = requests.post(url, data=div_payload, headers=header).text 
            div_info_ty = read_xml(r1)
            div_info_list.append(div_info_ty)
            todate_dt = bef_two_year
            bef_two_year -= relativedelta(years=2)
        else:
            fromdate_str = fromdate_dt.strftime('%Y%m%d')
            todate_str = todate_dt.strftime('%Y%m%d')
            div_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="divStatInfoPList" task="ksd.safe.bip.cnts.Company.process.EntrFnafInfoPTask"><RGT_STD_DT_FROM value="{0}"/><RGT_STD_DT_TO value="{1}"/><ISSUCO_CUSTNO value="{2}"/><KOR_SECN_NM value=""/><SECN_KACD value=""/><RGT_RSN_DTAIL_SORT_CD value=""/><LIST_TPCD value=""/><START_PAGE value="1"/><END_PAGE value="15"/><MENU_NO value="285"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01041V.xml"/></reqParam>'.format(fromdate_str, todate_str, cust_no)
            r1 = requests.post(url, data=div_payload, headers=header).text 
            div_info_ty = read_xml(r1)
            div_info_list.append(div_info_ty)
            break           

        
    div_info = pd.concat(div_info_list)
    
    schd = schedule[schedule['rgt_ranm'] == '배당/분배'].copy()
    schd = schd[schd['dt_tpnm'] == '권리락일']
    schd = schd[['issuco_custno','rgt_ranm','rgt_std_dt','dt_expry_dt']]
    div = div_info[div_info['kor_secn_nm'] == codeName][['rgt_std_dt','shotn_isin', 'kor_secn_nm', 'cash_aloc_amt']].copy()


    cash_amt = []
    for idx,std_dt in enumerate(schd['rgt_std_dt']):
        print(std_dt)
        print(div)
        cash = div[div['rgt_std_dt'] == std_dt]['cash_aloc_amt'].iloc[0]
        cash_amt.append(cash)
    schd['cash_aloc_amt'] = cash_amt


    schd.index = pd.to_datetime(schd['dt_expry_dt'])
    schd['cash_aloc_amt'] = schd['cash_aloc_amt'].apply(lambda x :int(x))
    schd.index.name = 'date'

    com['div'] = 0
    com_tmp = com.copy()
    for date in schd.index:
        com_tmp['div'].loc[date] = schd['cash_aloc_amt'].loc[date]

    factor = 1 - com_tmp['div'] / (com_tmp['tdd_clsprc'] - com_tmp['div'])

    com_tmp[['mktcap', 'list_shrs']] = com_tmp[['mktcap', 'list_shrs']].applymap(lambda x: int(x.replace(',','')))

    divider = com_tmp['list_shrs'].iloc[0]
    cls = com_tmp['mktcap'] / divider * 1000000
    cls = cls.apply(lambda x : int(round(x,0)))

    adj = cls * cum_mul(factor)
    return adj

# %%
df = get_adj_price('A005930', '20150101', '20200101')
df
# Out:
# 20150630
#    rgt_std_dt shotn_isin kor_secn_nm cash_aloc_amt
# 0    20191231     005930        삼성전자           354
# 2    20190930     005930        삼성전자           354
# 4    20190630     005930        삼성전자           354
# 6    20190331     005930        삼성전자           354
# 8    20181231     005930        삼성전자           354
# 10   20180930     005930        삼성전자           354
# 12   20180630     005930        삼성전자           354
# 14   20180331     005930        삼성전자         17700
# 0    20171231     005930        삼성전자         21500
# 2    20170930     005930        삼성전자          7000
# 4    20170630     005930        삼성전자          7000
# 6    20170331     005930        삼성전자          7000
# 8    20161231     005930        삼성전자         27500
# 10   20160630     005930        삼성전자          1000
# 0    20151231     005930        삼성전자         20000
# 2    20150630     005930        삼성전자          1000
# 20151231
#    rgt_std_dt shotn_isin kor_secn_nm cash_aloc_amt
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df)
plt.show()

# %%
url = 'http://www.seibro.or.kr/websquare/engine/proworks/callServletService.jsp'

header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/79.0.3945.130 Safari/537.36',
    'Accept': 'application/xml',
    'Referer': 'http://www.seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/company/BIP_CNTS01021V.xml'
}

# %%
fromdate = '20180101'
todate = '20200101'
cust_no = '593'

# %%
div_payload = '<?xml version="1.0" encoding="UTF-8" ?><reqParam action="divStatInfoPList" task="ksd.safe.bip.cnts.Company.process.EntrFnafInfoPTask"><RGT_STD_DT_FROM value="{0}"/><RGT_STD_DT_TO value="{1}"/><ISSUCO_CUSTNO value="{2}"/><KOR_SECN_NM value=""/><SECN_KACD value=""/><RGT_RSN_DTAIL_SORT_CD value=""/><LIST_TPCD value=""/><START_PAGE value="1"/><END_PAGE value="15"/><MENU_NO value="285"/><CMM_BTN_ABBR_NM value="allview,allview,print,hwp,word,pdf,searchIcon,seach,xls,link,link,wide,wide,top,"/><W2XPATH value="/IPORTAL/user/company/BIP_CNTS01041V.xml"/></reqParam>'.format(fromdate, todate, cust_no)
r1 = requests.post(url, data=div_payload, headers=header).text
div_info = read_xml(r1)
div_info
# Out:
#    rgt_std_dt th1_pay_term_begin_dt deli_dt shotn_isin kor_secn_nm list_tpnm  \
# 0    20181231              20190419             005930        삼성전자    유가증권시장
# 1    20181231              20190419             005935      삼성전자1우    유가증권시장
# 2    20180930              20181120             005930        삼성전자    유가증권시장
# 3    20180930              20181120             005935      삼성전자1우    유가증권시장
# 4    20180630              20180820             005930        삼성전자    유가증권시장
# 5    20180630              20180820             005935      삼성전자1우    유가증권시장
# 6    20180331              20180516             005930        삼성전자    유가증권시장
# 7    20180331              20180516             005935      삼성전자1우    유가증권시장
# 8    20171231              20180423             005930        삼성전자    유가증권시장
# 9    20171231              20180423             005935      삼성전자1우    유가증권시장
# 10   20170930              20171120             005930        삼성전자    유가증권시장
# ...

# %%
fromdate = '20150101'
todate = '20200101'
fromdate_dt = pd.to_datetime(fromdate)
todate_dt = pd.to_datetime(todate)
bef_two_year = todate_dt - relativedelta(years=2) 
bef_two_year> fromdate_dt

# %%
fromdate_dt = pd.to_datetime(fromdate)
todate_dt = pd.to_datetime(todate)

# %%
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
bef_two_year = todate_dt - relativedelta(years=2)

# %%
bef_two_year> fromdate_dt
# Out:
# True
