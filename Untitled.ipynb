# %%
import requests
import pandas as pd
import json

# %%
## 상장 회사 2355개 뽑기

# %%
otp1 = 'http://marketdata.krx.co.kr/contents/COM/GenerateOTP.jspx'

# %%
header = {
    'Referer': 'http://marketdata.krx.co.kr/mdi',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest'  
}

# %%
otp1_payload = {
    'bld': 'MKD/04/0406/04060100/mkd04060100_01',
    'name': 'form'
}

# %%
code = requests.post(otp1, data=otp1_payload, headers=header).text

# %%
main1 = 'http://marketdata.krx.co.kr/contents/MKD/99/MKD99000001.jspx'

# %%
main1_paylaod = {
    'market_gubun': 'ALL',
    'isu_cdnm': '전체',
    'sort_type': 'A',
    'lst_stk_vl': 1,
    'cpt': 1,
    'isu_cdnm': '전체',
    'pagePath': '/contents/MKD/04/0406/04060100/MKD04060100.jsp',
    'code': code
}

# %%
list1 = []
for i in range(1,249):
    main1_paylaod['curPage'] = i
    r = requests.post(main1, data=main1_paylaod, headers=header).text
    x = json.loads(r)['block1']
    df = pd.DataFrame(x)
    list1.append(df)

# %%
listed_com = pd.concat(list1)

# %%
## 상장 종목 2475개 뽑기

# %%
otp2 = 'http://marketdata.krx.co.kr/contents/COM/GenerateOTP.jspx'

# %%
otp2_payload = {
    'bld': 'COM/finder_stkisu',
    'name': 'form'
}

# %%
code2 = requests.post(otp2, data=otp2_payload, headers=header).text

# %%
main2 = 'http://marketdata.krx.co.kr/contents/MKD/99/MKD99000001.jspx'

# %%
main2_paylaod = {
    'no': 'P1',
    'mktsel': 'ALL',
    'pagePath': '/contents/COM/FinderStkIsu.jsp',
    'code': code2
}

# %%
list2 = []
for i in range(1,16):
    main2_paylaod['consonant'] = i
    r = requests.post(main2, data=main2_paylaod, headers=header).text
    x = json.loads(r)['block1']
    df = pd.DataFrame(x)
    list2.append(df)

# %%
full_code = pd.concat(list2)

# %%
len(full_code)
# Out:
# 2553

# %%
len(listed_com)
# Out:
# 2355

# %%
full_code.head(3)
# Out:
#   codeName     full_code marketName short_code
# 0      가비아  KR7079940003     KOSDAQ    A079940
# 1    가온미디어  KR7078890001     KOSDAQ    A078890
# 2     가온전선  KR7000500009      KOSPI    A000500

# %%
listed_com.head(3)
# Out:
#                            addr             cpt  iso_cd   isu_cd kor_cor_nm  \
# 0      서울특별시 금천구  시흥대로71길 30-1   22,386,071,500  원(KRW)  A060310         3S
# 1  서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)  46,822,295,000  원(KRW)  A095570     AJ네트웍스
# 2          서울특별시 마포구 양화로 188 -   66,237,805,000  원(KRW)  A006840      AK홀딩스
#
#    lst_stk_vl no par_pr std_ind_cd       std_ind_nm        tel_no totCnt
# 0  44,772,143  1    500     032902    특수 목적용 기계 제조업   02-896-9474   2355
# 1  46,822,295  2  1,000     147603  산업용 기계 및 장비 임대업  02-6363-9999   2355
# 2  13,247,561  3  5,000     116409           기타 금융업   02-768-2923   2355

# %%
pd.DataFrame()

# %%
full_code[full_code['short_code'] == 'F70901789']
# Out:
#      codeName     full_code marketName short_code
# 54  대신하임1817호  KR5709017895      KOSPI  F70901789

# %%
differ = full_code[full_code['short_code'].isin(dif)].copy()

# %%
differ = differ.sort_values('short_code', ascending =False)

# %%
differ.reset_index(drop=True, inplace=True)

# %%
differ_pref = differ.iloc[78:].copy()

# %%
differ_pref.sort_values('marketName')
# Out:
#        codeName     full_code marketName short_code
# 102      대호피앤씨우  KR7021041009     KOSDAQ    A021045
# 100       소프트센우  KR7032681009     KOSDAQ    A032685
# 92      루트로닉3우C  KR708537K039     KOSDAQ    A08537M
# 78     두산솔루스2우B  KR733637K028      KOSPI    A33637L
# 165     대한제당3우B  KR7001793009      KOSPI    A001799
# 164        코오롱우  KR7002021004      KOSPI    A002025
# 163    넥센타이어1우B  KR7002351005      KOSPI    A002355
# 162      진흥기업우B  KR7002781003      KOSPI    A002785
# 161     진흥기업2우B  KR7002782001      KOSPI    A002787
# 160       아모레G우  KR7002791002      KOSPI    A002795
# 159  아모레G3우(전환)  KR700279K010      KOSPI    A00279K
# 158       금호산업우  KR7002991008      KOSPI    A002995
# 157     코오롱글로벌우  KR7003071008      KOSPI    A003075
# 156       쌍용양회우  KR7003411006      KOSPI    A003415
# 155       유화증권우  KR7003461001      KOSPI    A003465
# 154      유안타증권우  KR7003471000      KOSPI    A003475
# 153       대한항공우  KR7003491008      KOSPI    A003495
# ...

# %%
differ.iloc[78:]
# Out:
#       codeName     full_code marketName short_code
# 78    두산솔루스2우B  KR733637K028      KOSPI    A33637L
# 79     두산솔루스1우  KR733637K010      KOSPI    A33637K
# 80    두산퓨얼셀2우B  KR733626K021      KOSPI    A33626L
# 81     두산퓨얼셀1우  KR733626K013      KOSPI    A33626K
# 82      SK케미칼우  KR728513K010      KOSPI    A28513K
# 83      크라운제과우  KR726490K013      KOSPI    A26490K
# 84        한진칼우  KR718064K016      KOSPI    A18064K
# 85        삼양사우  KR7145991006      KOSPI    A145995
# 86      코오롱인더우  KR7120111000      KOSPI    A120115
# 87     LG하우시스우  KR7108671009      KOSPI    A108675
# 88    CJ제일제당 우  KR7097951008      KOSPI    A097955
# 89    SK이노베이션우  KR7096771001      KOSPI    A096775
# 90     아모레퍼시픽우  KR7090431008      KOSPI    A090435
# 91      노루페인트우  KR7090351008      KOSPI    A090355
# 92     루트로닉3우C  KR708537K039     KOSDAQ    A08537M
# 93      대상홀딩스우  KR7084691005      KOSPI    A084695
# 94         GS우  KR7078931003      KOSPI    A078935
# ...

# %%
differ2 = differ.iloc[:78].copy()

# %%
differ2.sort_values('codeName')
# Out:
#                   codeName     full_code marketName short_code
# 46   GIB더드림프리미어혼합자산1호(종A1)  KR572501B953      KOSPI  F72501B95
# 44  GIB더드림프리미어혼합자산1호(종C-r)  KR572502B951      KOSPI  F72502B95
# 42  GIB더드림프리미어혼합자산1호(종C-s)  KR572503B959      KOSPI  F72503B95
# 52     KB 와이즈 스타 부동산 자 2 A  KR571901B964      KOSPI  F71901B96
# 50   KB 와이즈 스타 부동산 자 2 C-F  KR571902B962      KOSPI  F71902B96
# 48   KB 와이즈 스타 부동산 자 2 C-I  KR571903B960      KOSPI  F71903B96
# 53            KB와이즈스타부동산1A  KR571901B923      KOSPI  F71901B92
# 49          KB와이즈스타부동산1C-F  KR571903B929      KOSPI  F71903B92
# 51         KB와이즈스타부동산1C-퇴직  KR571902B921      KOSPI  F71902B92
# 47            나인트리부동산(종A1)  KR5725017739      KOSPI  F72501773
# 45           나인트리부동산(종C-i)  KR5725027738      KOSPI  F72502773
# 66           대신Japan하임03호A  KR570901B957      KOSPI  F70901B95
# 65         대신Japan하임03호C-I  KR570902B955      KOSPI  F70902B95
# 64         대신Japan하임03호C-W  KR570903B953      KOSPI  F70903B95
# ...

# %%
coms = []
for idx, com in differ.iterrows():
    if com['codeName'].find('우') == -1:
        coms.append(differ.iloc[idx])
#pd.concat(coms)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-dfdd8191c9f1> in <module>()
#       2 for idx, com in differ.iterrows():
#       3     if com['codeName'].find('우') == -1:
# ----> 4         coms.append(differ.iloc[idx])
#       5 #pd.concat(coms)
#
# ~\Anaconda3\envs\backtester\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~\Anaconda3\envs\backtester\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1828
#    1829             # validate the location
# -> 1830             self._is_valid_integer(key, axis)
#    1831
#    1832             return self._get_loc(key, axis=axis)
#
# ...

# %%
coms2 = []
for idx, com in differ.iterrows():
    if com['short_code'].find('F') != -1:
        coms2.append(com)
pd.DataFrame(pd.concat(coms2))
# Out:
#                                  0
# codeName              나인트리부동산(종A1)
# full_code             KR5725017739
# marketName                   KOSPI
# short_code               F72501773
# codeName             나인트리부동산(종C-i)
# full_code             KR5725027738
# marketName                   KOSPI
# short_code               F72502773
# codeName             대신Japan하임03호A
# full_code             KR570901B957
# marketName                   KOSPI
# short_code               F70901B95
# codeName           대신Japan하임03호C-I
# full_code             KR570902B955
# marketName                   KOSPI
# short_code               F70902B95
# codeName           대신Japan하임03호C-W
# full_code             KR570903B953
# marketName                   KOSPI
# short_code               F70903B95
# codeName                 대신하임1817호
# full_code             KR5709017895
# marketName                   KOSPI
# short_code               F70901789
# codeName                    도쿄오피스1
# full_code             KR57010177A4
# ...

# %%
x = {"DS1":[{"kor_shrt_isu_nm":"현대유퍼스트부동산25호 C-i","isu_cur_pr":"955","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"현대유퍼스트부동산25호 A","isu_cur_pr":"951","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"유경공모부동산2호ClassA","isu_cur_pr":"1,000","fluc_tp_cd":"3","prv_dd_cmpr":"0","isu_tr_vl":"5,250","isu_tr_amt":"5,250,000","isu_opn_pr":"1,000","isu_hg_pr":"1,000","isu_lw_pr":"1,000"},{"kor_shrt_isu_nm":"유경공모부동산1호ClassF","isu_cur_pr":"1,020","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"유경공모부동산2호ClassF","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"유경공모부동산1호ClassA","isu_cur_pr":"990","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스리테일287호 Class C-P","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스리테일287호 Class A","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스코어리테일302호A","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스리테일287호 Class C-I","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스229호 Class C-I","isu_cur_pr":"993","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스리테일194호","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스코어부동산126호 C-i","isu_cur_pr":"1,005","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스코어부동산제117호F","isu_cur_pr":"1,005","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스299호A","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스코어리테일302호C-I","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스글로벌281호 Class A","isu_cur_pr":"1,030","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스280호","isu_cur_pr":"1,005","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스239호 Class A","isu_cur_pr":"1,000","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스229호 Class A","isu_cur_pr":"998","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스204호 Class A","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스196호 Class A","isu_cur_pr":"560","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스187호","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스161호","isu_cur_pr":"915","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스코어부동산126호 A","isu_cur_pr":"9,000","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"이지스코어부동산제117호A","isu_cur_pr":"1,020","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"메리츠베트남주식혼합","isu_cur_pr":"846","fluc_tp_cd":"2","prv_dd_cmpr":"3","isu_tr_vl":"11,989","isu_tr_amt":"9,874,377","isu_opn_pr":"851","isu_hg_pr":"851","isu_lw_pr":"817"},{"kor_shrt_isu_nm":"맵스미국11호","isu_cur_pr":"1,165","fluc_tp_cd":"2","prv_dd_cmpr":"5","isu_tr_vl":"36,898","isu_tr_amt":"43,036,675","isu_opn_pr":"1,170","isu_hg_pr":"1,170","isu_lw_pr":"1,165"},{"kor_shrt_isu_nm":"맵스호주2호","isu_cur_pr":"930","fluc_tp_cd":"1","prv_dd_cmpr":"9","isu_tr_vl":"14","isu_tr_amt":"13,093","isu_opn_pr":"938","isu_hg_pr":"938","isu_lw_pr":"930"},{"kor_shrt_isu_nm":"맵스미국9-2호","isu_cur_pr":"1,135","fluc_tp_cd":"1","prv_dd_cmpr":"10","isu_tr_vl":"245,140","isu_tr_amt":"277,558,605","isu_opn_pr":"1,135","isu_hg_pr":"1,135","isu_lw_pr":"1,130"},{"kor_shrt_isu_nm":"맵스프런티어브라질1","isu_cur_pr":"267","fluc_tp_cd":"2","prv_dd_cmpr":"8","isu_tr_vl":"7,497","isu_tr_amt":"1,952,994","isu_opn_pr":"260","isu_hg_pr":"267","isu_lw_pr":"260"},{"kor_shrt_isu_nm":"하나대체일본부동산1호 C-I","isu_cur_pr":"977","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"하나대체일본부동산1호 C-W","isu_cur_pr":"977","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"하나대체일본부동산1호 A","isu_cur_pr":"977","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"하나대체미국LA부동산1호 F","isu_cur_pr":"990","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"하나대체티마크그랜드부동산1호 F","isu_cur_pr":"1,005","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"하나대체일본부동산1호 P","isu_cur_pr":"977","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"하나대체미국LA부동산1호 A","isu_cur_pr":"1,000","fluc_tp_cd":"1","prv_dd_cmpr":"2","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"하나대체나사부동산1호","isu_cur_pr":"947","fluc_tp_cd":"2","prv_dd_cmpr":"6","isu_tr_vl":"45,412","isu_tr_amt":"42,797,699","isu_opn_pr":"950","isu_hg_pr":"950","isu_lw_pr":"940"},{"kor_shrt_isu_nm":"하나대체티마크그랜드부동산1호 A","isu_cur_pr":"1,020","fluc_tp_cd":"3","prv_dd_cmpr":"0","isu_tr_vl":"10,000","isu_tr_amt":"10,200,000","isu_opn_pr":"1,020","isu_hg_pr":"1,020","isu_lw_pr":"1,020"},{"kor_shrt_isu_nm":"칸서스노을연료전지","isu_cur_pr":"1,315","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"신한BNPP서울시지하철9호선4호","isu_cur_pr":"1,000","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"GIB더드림프리미어혼합자산1호(종C-s)","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"신한BNPP서울시지하철9호선3호","isu_cur_pr":"1,010","fluc_tp_cd":"3","prv_dd_cmpr":"0","isu_tr_vl":"90","isu_tr_amt":"90,900","isu_opn_pr":"1,010","isu_hg_pr":"1,010","isu_lw_pr":"1,010"},{"kor_shrt_isu_nm":"GIB더드림프리미어혼합자산1호(종C-r)","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"나인트리부동산(종C-i)","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"GIB더드림프리미어혼합자산1호(종A1)","isu_cur_pr":"1,010","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"나인트리부동산(종A1)","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"KB 와이즈 스타 부동산 자 2 C-I","isu_cur_pr":"989","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"KB와이즈스타부동산1C-F","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"KB 와이즈 스타 부동산 자 2 C-F","isu_cur_pr":"989","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"KB와이즈스타부동산1C-퇴직","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"KB 와이즈 스타 부동산 자 2 A","isu_cur_pr":"960","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"KB와이즈스타부동산1A","isu_cur_pr":"1,015","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"멀티에셋월지급식안심튼튼제2호","isu_cur_pr":"955","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산4호 C-I","isu_cur_pr":"929","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산4호 A","isu_cur_pr":"980","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산3호 C-I","isu_cur_pr":"929","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산3호 A","isu_cur_pr":"980","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산2호 C-I","isu_cur_pr":"929","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산2호 A","isu_cur_pr":"980","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산1호 C-I","isu_cur_pr":"929","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈유럽오피스부동산1호 A","isu_cur_pr":"980","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"키움히어로즈미국물류부동산1호","isu_cur_pr":"950","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"대신Japan하임03호C-W","isu_cur_pr":"966","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"대신Japan하임03호C-I","isu_cur_pr":"963","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"대신Japan하임03호A","isu_cur_pr":"980","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"대신하임1817호","isu_cur_pr":"1,005","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"룩셈부르크코어오피스(파생형)(C-I)","isu_cur_pr":"994","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"룩셈부르크코어오피스(파생형)(A)","isu_cur_pr":"994","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"벨기에코어오피스부동산(C-I)","isu_cur_pr":"997","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"한국투자뉴욕오피스1호","isu_cur_pr":"980","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"한국투자도쿄한조몬오피스","isu_cur_pr":"1,050","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"벨기에코어오피스2호","isu_cur_pr":"980","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"밀라노부동산","isu_cur_pr":"990","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"벨기에코어오피스부동산(A)","isu_cur_pr":"1,000","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"도쿄중소형오피스1","isu_cur_pr":"1,060","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"},{"kor_shrt_isu_nm":"도쿄오피스1","isu_cur_pr":"1,095","fluc_tp_cd":"0","prv_dd_cmpr":"0","isu_tr_vl":"0","isu_tr_amt":"0","isu_opn_pr":"0","isu_hg_pr":"0","isu_lw_pr":"0"}]}

# %%
pd.DataFrame(x['DS1']).iloc[:50]
# Out:
#    fluc_tp_cd isu_cur_pr isu_hg_pr isu_lw_pr isu_opn_pr   isu_tr_amt  \
# 0           0        955         0         0          0            0
# 1           0        951         0         0          0            0
# 2           3      1,000     1,000     1,000      1,000    5,250,000
# 3           0      1,020         0         0          0            0
# 4           0      1,010         0         0          0            0
# 5           0        990         0         0          0            0
# 6           0      1,015         0         0          0            0
# 7           0      1,015         0         0          0            0
# 8           0      1,015         0         0          0            0
# 9           0      1,015         0         0          0            0
# 10          0        993         0         0          0            0
# 11          0      1,010         0         0          0            0
# 12          0      1,005         0         0          0            0
# ...
